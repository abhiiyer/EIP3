# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiiyer/EIP3/blob/master/Session%203/AbhishekIyer_CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
######## Implementation of Unpaired Image-to-Image Translation using Cycle-Consistent Adversarial Networks. ########

### Github link is https://github.com/eriklindernoren/Keras-GAN

# Step-1: Mount the Google Drive on Colab 

from google.colab import drive
drive.mount('/content/drive')

# Step-2: Important is to downgrade scipy to 1.1.0 (!pip install scipy==1.1.0) and restart run-time

# !pip install scipy==1.1.0

# Step-3: Download the dataset 

# !git clone https://github.com/eriklindernoren/Keras-GAN.git
# %cd /content/Keras-GAN/cyclegan
# !ls
# !bash download_dataset.sh apple2orange
# !cp -r datasets/ /content/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 1.4MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.16.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
# Successfully installed scipy-1.1.0
# Cloning into 'Keras-GAN'...
# remote: Enumerating objects: 3469, done.
# remote: Total 3469 (delta 0), reused 0 (delta 0), pack-reused 3469
# Receiving objects: 100% (3469/3469), 88.40 MiB | 32.46 MiB/s, done.
# Resolving deltas: 100% (556/556), done.
# /content/Keras-GAN/cyclegan
# cyclegan.py  data_loader.py  download_dataset.sh  images  saved_model
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2019-08-26 14:23:22--  https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/apple2orange.zip
# Resolving people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.189.73
# Connecting to people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.189.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78456409 (75M) [application/zip]
# Saving to: ‘./datasets/apple2orange.zip’
#
# ./datasets/apple2or 100%[===================>]  74.82M  83.1MB/s    in 0.9s
#
# 2019-08-26 14:23:23 (83.1 MB/s) - ‘./datasets/apple2orange.zip’ saved [78456409/78456409]
#
# Archive:  ./datasets/apple2orange.zip
#    creating: ./datasets/apple2orange/trainA/
#   inflating: ./datasets/apple2orange/trainA/n07740461_6908.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7635.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_586.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9813.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6835.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2818.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2918.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1213.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2476.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13596.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4093.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14738.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6477.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11356.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7594.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5119.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10458.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11597.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_318.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5822.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5127.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9944.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6967.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2912.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6899.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2433.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12748.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11819.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7165.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_354.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6193.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5645.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14954.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14869.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6973.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3892.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12129.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11673.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2105.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4427.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_312.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12055.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2077.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_494.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10664.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_965.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1848.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_165.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3777.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10369.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14638.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_708.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1978.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6768.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1787.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7446.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14327.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2115.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10357.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13465.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10284.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3664.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7627.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_964.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13482.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5266.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8478.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11408.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8012.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10894.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7402.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14895.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7004.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11602.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9786.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4936.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2204.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2128.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15239.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_738.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7603.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8617.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1494.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11418.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13528.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10266.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_272.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14475.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10183.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7405.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4278.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2263.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3433.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_492.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14022.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14278.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12636.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6415.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11114.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8774.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4467.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_287.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6957.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5983.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4487.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10037.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4945.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7964.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4952.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7392.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6605.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4009.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2243.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13713.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7894.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5775.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10994.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5218.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10747.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13863.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10584.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12888.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4662.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7257.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10218.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14959.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8269.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8232.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_763.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9636.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5156.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3464.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_242.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10239.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8762.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15064.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2683.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13725.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7116.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4503.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8368.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11864.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14586.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10554.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5242.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5697.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9083.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_166.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2408.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12962.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13395.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7393.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12998.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13832.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8277.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10257.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2616.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14116.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2874.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6068.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13477.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1679.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13382.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6793.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_593.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10577.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14192.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11095.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5024.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14237.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8957.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4846.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1352.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11678.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2239.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11247.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5378.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9927.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4834.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14525.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15054.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1556.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1696.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8915.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14612.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7184.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2587.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13673.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4017.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8577.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10722.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_787.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3352.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6149.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1313.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9495.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5755.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3485.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15013.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9047.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14913.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14744.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7002.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_663.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6126.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1723.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5964.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9902.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14862.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6948.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_183.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8176.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14516.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8222.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8673.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10129.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3895.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6834.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4412.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12305.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7827.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2326.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2798.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14724.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4445.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2525.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7387.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6216.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4399.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12372.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1629.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5856.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6695.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5962.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8068.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2583.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14593.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10166.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1778.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_526.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2435.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2168.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12937.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1889.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14257.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_656.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_384.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5043.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4582.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4686.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5857.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10363.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14818.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_234.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13335.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1844.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8842.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_128.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13655.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6236.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2672.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1438.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2176.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10104.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5233.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14886.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14824.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_106.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15098.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5168.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9687.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14903.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10508.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10019.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3043.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14542.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1937.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8836.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4415.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1582.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8553.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_818.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2468.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1656.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_583.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5716.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14722.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9252.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4773.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_862.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3322.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5435.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2443.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4813.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8479.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12614.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3586.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7793.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13109.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1834.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8132.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13806.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10885.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4805.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1338.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15074.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5077.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14994.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10273.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5894.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10762.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6976.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12382.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10756.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6707.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6422.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_158.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14746.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3187.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6918.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7383.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_953.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2405.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8834.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10724.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8902.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6784.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2739.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12693.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10643.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2194.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_533.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4523.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1734.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12048.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12385.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6084.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10639.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4238.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11044.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10819.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6775.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13328.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7909.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14646.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14224.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9849.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3458.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4054.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10986.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6587.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13184.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_385.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13368.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7925.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_879.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_55.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11082.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14978.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3178.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10657.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1163.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3937.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7464.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6292.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11254.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3074.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8679.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5505.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1742.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_803.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7243.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_239.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1254.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4783.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2199.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11143.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3476.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6178.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12355.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10403.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1926.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_236.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14639.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1958.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14403.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14035.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9582.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12807.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13013.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8166.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5532.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_782.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13066.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11616.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7194.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4585.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_948.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9092.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8956.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6895.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5067.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15196.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5786.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3736.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_237.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5826.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4199.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5876.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4376.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12507.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11855.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5486.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9773.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1949.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8448.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8032.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3429.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12298.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6759.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1966.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1402.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6433.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6815.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7372.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8389.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14703.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13284.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7798.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12327.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14414.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12953.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1374.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7208.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8689.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5182.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_904.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3095.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1954.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10535.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5245.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7498.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1223.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1354.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_222.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5468.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14543.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12297.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9026.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7708.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7503.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3073.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4545.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1823.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11938.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13899.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2552.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8904.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11833.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9835.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_574.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12228.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13958.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13153.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6106.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1698.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1677.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12713.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1859.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1993.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6616.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7094.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2278.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11613.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1985.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5122.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5135.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6394.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7887.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1283.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14825.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1754.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14273.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1164.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7974.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4039.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3139.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2359.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8764.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8062.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3976.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11258.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6144.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7769.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8007.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7659.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6469.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2656.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9747.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_329.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7133.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4398.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12215.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7637.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5173.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6056.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9518.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1828.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14645.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5466.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2136.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12564.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12034.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7487.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3569.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14919.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10335.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5079.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12867.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3398.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13198.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14236.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8983.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11797.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_173.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12056.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6944.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8464.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12993.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10717.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7615.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7638.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_226.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5968.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3159.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3602.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1239.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8406.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1685.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6352.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1277.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6743.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3652.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14797.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3123.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6507.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7805.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13907.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12556.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4299.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2787.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9294.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_543.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12929.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1169.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6838.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12374.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6008.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2122.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13943.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_614.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_666.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5146.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13218.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14439.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11069.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9067.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2588.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11225.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4816.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2867.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10797.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1563.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4644.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10374.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13137.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13763.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11403.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1623.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_247.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_832.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_524.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4566.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10336.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13225.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7874.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2142.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9816.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14619.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8458.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3036.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5848.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8399.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_649.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7286.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5794.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_488.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7523.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6476.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6877.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10997.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5882.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9338.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1923.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2307.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5037.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6658.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6544.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13552.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3498.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5567.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_325.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10647.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11094.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5362.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3248.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10242.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7448.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3535.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14893.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2099.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11457.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9549.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3454.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1735.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6688.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14713.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14568.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10067.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13633.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1612.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9442.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8857.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2483.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2349.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_198.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1713.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3503.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4836.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7422.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2522.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_15087.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6157.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6632.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7878.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4203.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11699.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5835.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8578.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11548.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1803.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3865.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3289.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10442.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12475.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8892.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14729.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11134.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7079.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1647.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_11267.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4618.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12402.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5345.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12855.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_5735.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3063.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7614.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_3776.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7145.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10074.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6947.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_785.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7865.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9537.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10517.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12737.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4019.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6143.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_2246.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12894.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8178.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_1979.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_928.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12136.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13233.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13324.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4602.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_10419.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_14889.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6305.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_8597.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_13048.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4163.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_9023.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_4249.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_12537.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_6746.jpg
# ...
#   inflating: ./datasets/apple2orange/testA/n07740461_14450.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1990.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8411.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3151.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10080.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7471.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11221.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8531.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4331.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10571.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12921.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2930.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7161.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7371.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13391.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8220.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_890.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3960.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13091.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10940.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14501.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11910.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14760.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5741.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9051.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6061.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12751.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8560.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2970.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14211.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9461.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12540.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14520.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6780.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3081.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3561.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13851.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11391.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14551.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1690.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4780.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9010.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2461.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2040.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6661.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14531.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14300.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14570.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5660.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7980.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11260.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13800.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6220.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_15010.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1171.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3640.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_950.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14621.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12071.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8391.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1131.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_750.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2210.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5141.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14341.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3520.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13151.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1580.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2550.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6151.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8640.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11040.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13950.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5520.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1680.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2960.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_350.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7270.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2510.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13901.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_790.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_91.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10311.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12630.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9141.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3571.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1261.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12841.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10750.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1800.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9091.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7220.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3210.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14811.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8271.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7140.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13171.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4891.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7200.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1930.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1490.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2130.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_15281.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10950.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1141.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4681.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7771.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_240.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1410.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1030.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7700.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6691.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2181.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2131.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_451.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13030.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14750.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1371.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6170.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14510.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1631.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3881.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11871.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_971.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3410.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6001.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8181.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11130.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13701.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11361.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_41.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7141.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8820.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11891.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3211.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7831.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8400.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7350.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5831.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11121.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_111.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2561.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9560.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3530.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14740.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2301.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10371.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7510.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6611.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14600.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9341.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11651.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12010.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1250.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_780.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2770.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1191.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7261.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9070.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_40.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6781.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6901.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2500.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2840.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5421.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2151.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13931.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13101.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9451.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10011.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7610.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4991.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3260.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3970.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13390.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1470.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12101.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1140.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2921.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12121.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7591.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10951.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6701.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_81.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2371.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_411.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4750.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14721.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7340.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10651.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3651.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8710.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_4491.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14960.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_51.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12300.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14101.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8851.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6011.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10211.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8130.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1761.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11801.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9901.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1790.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11041.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1480.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1780.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3980.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_510.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_10681.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5871.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14860.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_11770.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_13580.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1560.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12350.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_5380.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_230.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2101.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_760.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1840.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_600.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2701.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6690.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8780.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3031.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1190.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7661.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_20.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3420.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3670.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14821.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12930.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6640.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_2520.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_8810.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_9980.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1541.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14931.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_490.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_3720.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_1661.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7841.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_601.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_6120.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_14791.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_7681.jpg
#   inflating: ./datasets/apple2orange/testA/n07740461_12990.jpg

# %% [markdown]
# ## CYCLEGAN :
# ---
#
# ## *CycleGAN for Unpaired Image-to-Image Translation*  (*Implemention of CycleGAN for Apple2Orange Dataset*)

# %% [markdown]
# ## Image to Image Translation Problems
#
# Image-to-Image translation is a class of computer vision and graphics problems, where the goal is to learn the mapping between an input domain to an output domain.
#
# Image-to-image translation is a general task where an image from one domain is converted to a corresponding image in another domain.
#
# Traditionally different approaches have been proposed depending on whether aligned image pairs or two sets of (unaligned) examples from both domains are available for training. While paired training samples might be difficult to obtain, the unpaired setup leads to a highly under-constrained problem and inferior results.

# %% [markdown]
# <a class="anchor" id="2"></a>
# ## Solving an Image to Image Translation Problems
#
# Many vision and graphics problems such as converting grayscale to colour images, satellite images to maps, sketches to photographs, and paintings to photographs can be seen as image-to-image translation tasks.
#
# Traditionally,each problem has been tackled with specific architectures and loss functions that do not generalize well to other tasks. Recently, Generative Adversarial Networks (GANs) have provided an alternative approach, where the loss function is learned from the data instead of defining it manually.Impressive results have been demonstrated in several areas such as image inpainting, style transfer,super-resolution and image colorisation. The Image-to-Image problems are overcomed by th below two approaches.
#
# <a class="anchor" id="2.1"></a>
# ### Using image-to-image translation using paired training samples
#
# Conditional GAN architectures have been widely applied in image-to-image translation tasks where sufficient amount of paired training examples are available.In particular, proposed a general purpose image to image translator "pix2pix" for various applications such as semantic maps to real image, edges to shoe images, and gray to color images.
#
#
# <a class="anchor" id="2.2"></a>
# ### Using image-to-image translation using unpaired training samples
#
# Three concurrent works "cycleGAN", "DiscoGAN" and "DualGAN" propose architectures consisting of two generator-discriminator pairs. The first pair learns a forward mapping from source to target domain, while the second pair learns the inverse
# of it. Both pairs are trained simultaneously using adversarial losses and an additional loss that encourages cascaded mapping to reproduce the original input image (referred as cycle consistency loss).
#
# The basic idea of Image to Image Translation is illustrated in the image below:
#
# ![Image to Image Translation](https://mikigom.github.io/img/pixcyccompare.png)
#
# Left: Traditional training data, comprising training examples {𝑥𝑖, 𝑦𝑖}𝑖=1 𝑁, where𝑥𝑖 and 𝑦𝑖are an aligned pair.
# CycleGAN addresses the situation where paired data is unavailable, it deals with a source set {𝑥} 𝑖=1 𝑁 (𝑥𝑖 ∈ 𝑋) and a target
# set {𝑦} 𝑖=1 𝑁 (𝑦𝑖 ∈ 𝑌)(right), with no alignment of specific 𝑥𝑖 -s with specific 𝑦𝑖 -s.

# %% [markdown]
# <a class="anchor" id="3"></a>
# ## Generative Adversarial Network(GAN) Overview
#
# Generative adversarial networks (GANs), introduced in 2014 by Goodfellow are an alternative to VAEs for learning latent spaces of images. They enable the generation of fairly realistic synthetic images by forcing the generated images to be statistically
# almost indistinguishable from real ones.
#
# An intuitive way to understand GANs is to imagine a forger trying to create a fake Picasso painting. At first, the forger is pretty bad at the task. He mixes some of his fakes with authentic Picassos and shows them all to an art dealer. The art dealer makes an authenticity assessment for each painting and gives the forger feedback about what makes a Picasso look like a Picasso. The forger goes back to his studio to prepare some new fakes. As times goes on, the forger becomes increasingly competent at imitating the style of Picasso, and the art dealer becomes increasingly expert at spotting fakes. In the end, they have on their hands some excellent fake Picassos.
#
#
# The GAN comprises of two networks:
#
# ![gan](https://i2.wp.com/www.kdnuggets.com/wp-content/uploads/generative-adversarial-network.png)

# %% [markdown]
# <a class="anchor" id="4"></a>
# ## Unpaired Image-to-Image Translation using CycleGAN
#
# <a class="anchor" id="4.1"></a>
# ### CycleGAN Overview
#
# CycleGAN is used to image-to-image translation without input-output pairs.In Image-to-image translation, the network need to learn the mapping between an input image and output image using a training set of aligned image pairs. This is a major problem for many applications as paired training data is not available.
#
# CycleGANs enable learning a mapping from one domain X to another domain Y without having to find
# perfectly matched training pairs. CycleGAN is an approach for learning to translate an image between domains in the absence of paired examples.
#
# The CycleGAN algorithm learns to automatically “translate” an image between two “domains”, by training on two unordered image collections.
#
# ![cycleGAN image](https://junyanz.github.io/CycleGAN/images/teaser.jpg)
#
# (left) Monet painting and landscape photo from Flickr; (center) zebras and horse from ImageNet; (right) summer and winter Yosemite photos from Flickr.
#
# The novelty of CycleGAN is its ability to learn to transform between domains without one-to-one paired training data from source and target domains. Most existing methods rely on paired examples for training. CycleGAN overcomes the need for a corresponding image in the target domain by a two-step transformation of source domain image-first mapping it to target domain and then back to the original image.
#
# CycleGAN employs Cycle Consistency using transitivity as a way to gauge successful translation. A generator network mapping the image to target domain is pitted against an adversarial discriminator network to improve the quality of generated images.

# %% [markdown]
# #### Discriminator Network:
#
# Takes as input an image (real or synthetic), and predicts whether the image came from the training set or was created by the generator network.
#
# Discriminator Network evaluates the authenticity of each data instance. The discriminator decides whether each instance of data it reviews belongs to the actual training dataset or Generated fake data.
#
# Discriminator Network interprets and differentiates whether the input data is Real or Fake.
#
#
# ### Adversarial Networks
#
# We have a generator network and discriminator network playing against each other. The generator tries to produce samples from the desired distribution and the discriminator tries to predict if the sample is from the actual distribution or produced by the generator. The generator and discriminator are trained jointly. The effect this has is that eventually the generator learns to approximate the underlying distribution completely and the discriminator is left guessing randomly.
#
#
# ### Cycle-Consistent
#
# The above adversarial method of training has a problem though. Quoting the authors of the original paper:
# Adversarial training can, in theory, learn mappings  G  and  F  that produce outputs identically distributed as target domains  Y  and  X  respectively. However, with large enough capacity, a network can map the same set of input images to any random permutation of images in the target domain, where any of the learned mappings can induce an output distribution that matches the target distribution. Thus, an adversarial loss alone cannot guarantee that the learned function can map an individual input  xi  to a desired output  yi .
#
# To regularize the model, the authors introduce the constraint of cycle-consistency - if we transform from source distribution to target and then back again to source distribution, we should get samples from our source distribution.

# %% [markdown]
# <a class="anchor" id="5"></a>
# ### CycleGAN Network Architecture
#
#
# ![Cyclicgan Architecture](https://junyanz.github.io/CycleGAN/images/cyclegan_blogs.jpg)
#
#
# In a paired dataset, every image, say  imgA , is manually mapped to some image, say  imgB , in target domain, such that they share various features. Features that can be used to map an image  (imgA/imgB)  to its correspondingly mapped counterpart  (imgB/imgA) . Basically, pairing is done to make input and output share some common features. This mapping defines meaningful transformation of an image from one damain to another domain. So, when we have paired dataset, generator must take an input, say  inputA , from domain  DA  and map this image to an output image, say  genB , which must be close to its mapped counterpart. But we don't have this luxury in unpaired dataset, there is no pre-defined meaningful transformation that we can learn, so, we will create it. We need to make sure that there is some meaningful relation between input image and generated image. So, authors tried to enforce this by saying that Generator will map input image  (inputA)  from domain  DA  to some image in target domain  DB , but to make sure that there is meaningful relation between these images, they must share some feature, features that can be used to map this output image back to input image, so there must be another generator that must be able to map back this output image back to original input. So, you can see this condition defining a meaningful mapping between  inputA  and  genB .
#
# In a nutshell, the model works by taking an input image from domain  DA  which is fed to our first generator  GeneratorA→B  whose job is to transform a given image from domain  DA  to an image in target domain  DB . This new generated image is then fed to another generator  GeneratorB→A  which converts it back into an image,  CyclicA , from our original domain  DA  (think of autoencoders, except that our latent space is  Dt ). And as we discussed in above paragraph, this output image must be close to original input image to define a meaningful mapping that is absent in unpaired dataset.
#
# As you can see in above figure, two inputs are fed into each discriminator(one is original image corresponding to that domain and other is the generated image via a generator) and the job of discriminator is to distinguish between them, so that discriminator is able to defy the adversary (in this case generator) and reject images generated by it. While the generator would like to make sure that these images get accepted by the discriminator, so it will try to generate images which are very close to original images in Class  DB . (In fact, the generator and discriminator are actually playing a game whose Nash equilibrium is achieved when the generator's distribution becomes same as the desired distribution)

# %%
import scipy
from glob import glob
import numpy as np

class DataLoader():
  
    def __init__(self, dataset_name, img_res=(128, 128)):
        print("Inside the constructor")
        print("dataset_name is ",dataset_name)
        self.dataset_name = dataset_name
        self.img_res = img_res

    def load_data(self, domain, batch_size=1, is_testing=False):
        data_type = "train%s" % domain if not is_testing else "test%s" % domain
        path = glob('./datasets/%s/%s/*' % (self.dataset_name, data_type))

        batch_images = np.random.choice(path, size=batch_size)

        imgs = []
        for img_path in batch_images:
            img = self.imread(img_path)
            if not is_testing:
                img = scipy.misc.imresize(img, self.img_res)

                if np.random.random() > 0.5:
                    img = np.fliplr(img)
            else:
                img = scipy.misc.imresize(img, self.img_res)
            imgs.append(img)

        imgs = np.array(imgs)/127.5 - 1.

        return imgs

    def load_batch(self, batch_size=1, is_testing=False):
        print("Inside load_batch() method")
        data_type = "train" if not is_testing else "val"
        path_A = glob('/content/datasets/%s/%sA/*' % (self.dataset_name, data_type))
        path_B = glob('/content/datasets/%s/%sB/*' % (self.dataset_name, data_type))

        self.n_batches = int(min(len(path_A), len(path_B)) / batch_size)
        total_samples = self.n_batches * batch_size

        # Sample n_batches * batch_size from each path list so that model sees all
        # samples from both domains
        path_A = np.random.choice(path_A, total_samples, replace=False)
        path_B = np.random.choice(path_B, total_samples, replace=False)

        for i in range(self.n_batches-1):
            batch_A = path_A[i*batch_size:(i+1)*batch_size]
            batch_B = path_B[i*batch_size:(i+1)*batch_size]
            imgs_A, imgs_B = [], []
            for img_A, img_B in zip(batch_A, batch_B):
                img_A = self.imread(img_A)
                img_B = self.imread(img_B)

                img_A = scipy.misc.imresize(img_A, self.img_res)
                img_B = scipy.misc.imresize(img_B, self.img_res)

                if not is_testing and np.random.random() > 0.5:
                        img_A = np.fliplr(img_A)
                        img_B = np.fliplr(img_B)

                imgs_A.append(img_A)
                imgs_B.append(img_B)

            imgs_A = np.array(imgs_A)/127.5 - 1.
            imgs_B = np.array(imgs_B)/127.5 - 1.

            yield imgs_A, imgs_B

    def load_img(self, path):
        img = self.imread(path)
        img = scipy.misc.imresize(img, self.img_res)
        img = img/127.5 - 1.
        return img[np.newaxis, :, :, :]

    def imread(self, path):
        return scipy.misc.imread(path, mode='RGB').astype(np.float)

# %%
from keras.layers import Layer, InputSpec
from keras import initializers, regularizers, constraints
from keras import backend as K


class InstanceNormalization(Layer):
    """Instance normalization layer.
    Normalize the activations of the previous layer at each step,
    i.e. applies a transformation that maintains the mean activation
    close to 0 and the activation standard deviation close to 1.
    # Arguments
        axis: Integer, the axis that should be normalized
            (typically the features axis).
            For instance, after a `Conv2D` layer with
            `data_format="channels_first"`,
            set `axis=1` in `InstanceNormalization`.
            Setting `axis=None` will normalize all values in each
            instance of the batch.
            Axis 0 is the batch dimension. `axis` cannot be set to 0 to avoid errors.
        epsilon: Small float added to variance to avoid dividing by zero.
        center: If True, add offset of `beta` to normalized tensor.
            If False, `beta` is ignored.
        scale: If True, multiply by `gamma`.
            If False, `gamma` is not used.
            When the next layer is linear (also e.g. `nn.relu`),
            this can be disabled since the scaling
            will be done by the next layer.
        beta_initializer: Initializer for the beta weight.
        gamma_initializer: Initializer for the gamma weight.
        beta_regularizer: Optional regularizer for the beta weight.
        gamma_regularizer: Optional regularizer for the gamma weight.
        beta_constraint: Optional constraint for the beta weight.
        gamma_constraint: Optional constraint for the gamma weight.
    # Input shape
        Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a Sequential model.
    # Output shape
        Same shape as input.
    # References
        - [Layer Normalization](https://arxiv.org/abs/1607.06450)
        - [Instance Normalization: The Missing Ingredient for Fast Stylization](
        https://arxiv.org/abs/1607.08022)
    """
    def __init__(self,
                 axis=None,
                 epsilon=1e-3,
                 center=True,
                 scale=True,
                 beta_initializer='zeros',
                 gamma_initializer='ones',
                 beta_regularizer=None,
                 gamma_regularizer=None,
                 beta_constraint=None,
                 gamma_constraint=None,
                 **kwargs):
        super(InstanceNormalization, self).__init__(**kwargs)
        self.supports_masking = True
        self.axis = axis
        self.epsilon = epsilon
        self.center = center
        self.scale = scale
        self.beta_initializer = initializers.get(beta_initializer)
        self.gamma_initializer = initializers.get(gamma_initializer)
        self.beta_regularizer = regularizers.get(beta_regularizer)
        self.gamma_regularizer = regularizers.get(gamma_regularizer)
        self.beta_constraint = constraints.get(beta_constraint)
        self.gamma_constraint = constraints.get(gamma_constraint)

    def build(self, input_shape):
        ndim = len(input_shape)
        if self.axis == 0:
            raise ValueError('Axis cannot be zero')

        if (self.axis is not None) and (ndim == 2):
            raise ValueError('Cannot specify axis for rank 1 tensor')

        self.input_spec = InputSpec(ndim=ndim)

        if self.axis is None:
            shape = (1,)
        else:
            shape = (input_shape[self.axis],)

        if self.scale:
            self.gamma = self.add_weight(shape=shape,
                                         name='gamma',
                                         initializer=self.gamma_initializer,
                                         regularizer=self.gamma_regularizer,
                                         constraint=self.gamma_constraint)
        else:
            self.gamma = None
        if self.center:
            self.beta = self.add_weight(shape=shape,
                                        name='beta',
                                        initializer=self.beta_initializer,
                                        regularizer=self.beta_regularizer,
                                        constraint=self.beta_constraint)
        else:
            self.beta = None
        self.built = True

    def call(self, inputs, training=None):
        input_shape = K.int_shape(inputs)
        reduction_axes = list(range(0, len(input_shape)))

        if self.axis is not None:
            del reduction_axes[self.axis]

        del reduction_axes[0]

        mean = K.mean(inputs, reduction_axes, keepdims=True)
        stddev = K.std(inputs, reduction_axes, keepdims=True) + self.epsilon
        normed = (inputs - mean) / stddev

        broadcast_shape = [1] * len(input_shape)
        if self.axis is not None:
            broadcast_shape[self.axis] = input_shape[self.axis]

        if self.scale:
            broadcast_gamma = K.reshape(self.gamma, broadcast_shape)
            normed = normed * broadcast_gamma
        if self.center:
            broadcast_beta = K.reshape(self.beta, broadcast_shape)
            normed = normed + broadcast_beta
        return normed

    def get_config(self):
        config = {
            'axis': self.axis,
            'epsilon': self.epsilon,
            'center': self.center,
            'scale': self.scale,
            'beta_initializer': initializers.serialize(self.beta_initializer),
            'gamma_initializer': initializers.serialize(self.gamma_initializer),
            'beta_regularizer': regularizers.serialize(self.beta_regularizer),
            'gamma_regularizer': regularizers.serialize(self.gamma_regularizer),
            'beta_constraint': constraints.serialize(self.beta_constraint),
            'gamma_constraint': constraints.serialize(self.gamma_constraint)
        }
        base_config = super(InstanceNormalization, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
# Out:
# Using TensorFlow backend.

# %%
from __future__ import print_function, division
import scipy

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
import datetime
import matplotlib.pyplot as plt
import sys
import numpy as np
import os

# %%
 # Input shape
img_rows = 128
img_cols = 128
channels = 3
img_shape = (img_rows, img_cols, channels)

 # Configure data loader
dataset_name = 'apple2orange'
data_loader = DataLoader(dataset_name=dataset_name, img_res=(img_rows, img_cols))
# Out:
# Inside the constructor
# dataset_name is  apple2orange

# %%
 # Calculate output shape of D (PatchGAN)
patch = int(img_rows / 2**4)
disc_patch = (patch, patch, 1)
print(disc_patch)

# Number of filters in the first layer of G and D
gf = 32
df = 64

 # Loss weights
lambda_cycle = 10.0                    # Cycle-consistency loss
lambda_id = 0.1 * lambda_cycle    # Identity loss
optimizer = Adam(0.0002, 0.5)
# Out:
# (8, 8, 1)

# %%
def conv2d(layer_input, filters, f_size=4):
#Layers used during downsampling
    d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
    d = LeakyReLU(alpha=0.2)(d)
    d = InstanceNormalization()(d)
    return d

# %%
def deconv2d(layer_input, skip_input, filters, f_size=4, dropout_rate=0):
#Layers used during upsampling
    u = UpSampling2D(size=2)(layer_input)
    u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u)
    if dropout_rate:
        u = Dropout(dropout_rate)(u)
    u = InstanceNormalization()(u)
    u = Concatenate()([u, skip_input])
    return u

# %% [markdown]
# ### Building Generator
#
# First we will build the a class representing our generators, which are comprised of 3 main components:
#
# ![Generator](https://hardikbansal.github.io/CycleGANBlog/images/Generator.jpg)
#
# 1) Encoder
#
# 2) Transformer
#
# 3) Decoder.
#
# The Generator model is based on the U-net architecture.
#
#
# #### Encoder
#
#  In the encoding step of the generator, what we're doing is essentially learning the features of an image using a convolutional neural network (CNN). Intuitively, CNNs learn features of an image by examining the spatial relationships between smaller regions by applying kernels (or filters) on the original image.
#
# The input size [256,256,3]is reshaped to [128,128,3] . The first step is extracting the features from an image which is done a convolution network. As input a convolution network takes an image, size of filter window that we move over input image to extract out features and the stride size to decide how much we will move filter window after each step. So the first layer of encoding looks like this:
#
# #### Decoder
# Very similar in structure to the encoder, the decoder reverses the effects of the encoder to generate an image in our target domain G(x) from its feature vector.

# %%
def build_generator():
#U-Net Generator      

# Image input
    d0 = Input(shape=img_shape)

# Downsampling
    d1 = conv2d(d0, gf)
    d2 = conv2d(d1, gf*2)
    d3 = conv2d(d2, gf*4)
    d4 = conv2d(d3, gf*8)

# Upsampling
    u1 = deconv2d(d4, d3, gf*4)
    u2 = deconv2d(u1, d2, gf*2)
    u3 = deconv2d(u2, d1, gf)

    u4 = UpSampling2D(size=2)(u3)
    output_img = Conv2D(channels, kernel_size=4, strides=1, padding='same', activation='tanh')(u4)

    return Model(d0, output_img)

# %%
def d_layer(layer_input, filters, f_size=4, normalization=True):
#Discriminator layer
    d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
    d = LeakyReLU(alpha=0.2)(d)
    if normalization:
        d = InstanceNormalization()(d)
    return d

# %% [markdown]
# <a class="anchor" id="6.2"></a>
# ### Building Descriminator
#
# Using the general purpose functions above, we can also define our discriminator network, which is simply a series of CNN layers that ultimately reduces the output to 1 dimensional prediction (real/fake).
#
# ![Descriminator](https://image.slidesharecdn.com/kaonetv2-facetranslation-171029102202/95/kaonet-v2-face-translation-using-cyclegan-25-638.jpg?cb=1509275338)
#
# The discriminator is simply a convolution network in our case. First, we will extract the features from the image

# %%
def build_discriminator():       

    img = Input(shape=img_shape)

    d1 = d_layer(img, df, normalization=False)
    d2 = d_layer(d1, df*2)
    d3 = d_layer(d2, df*4)
    d4 = d_layer(d3, df*8)

    validity = Conv2D(1, kernel_size=4, strides=1, padding='same')(d4)
    return Model(img, validity)

# %% [markdown]
# We now have two main components of the model, namely Generator and Discriminator, and since we want to make this model work in both the direction i.e., from A→B and from B→A , we will have two Generators, namely GeneratorA→B and GeneratorB→A , and two Discriminators, namely DiscriminatorA and DiscriminatorB .

# %% [markdown]
# #### Discriminator loss
#
# Discriminator must be trained such that recommendation for images from category A must be as close to 1, and vice versa for discriminator B. So Discriminator A would like to minimize  (DiscriminatorA(a)−1)2  and same goes for B as well. This can be implemented as:

# %%
# Build and compile the discriminators
d_A = build_discriminator()
d_B = build_discriminator()
print(d_A.summary())

d_A.compile(loss='mse',optimizer=optimizer,metrics=['accuracy'])
d_B.compile(loss='mse',optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0826 14:24:36.885968 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0826 14:24:36.889934 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0826 14:24:36.897962 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0826 14:24:37.335507 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        3136
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       131200
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# instance_normalization_1 (In (None, 32, 32, 128)       2
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       524544
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# instance_normalization_2 (In (None, 16, 16, 256)       2
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 512)         2097664
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 8, 8, 512)         0
# _________________________________________________________________
# instance_normalization_3 (In (None, 8, 8, 512)         2
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 1)           8193
# =================================================================
# Total params: 2,764,743
# Trainable params: 2,764,743
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Build the generators
g_AB = build_generator()
g_BA = build_generator()
print(g_AB.summary())
# Out:
# W0826 14:24:39.995177 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 32)   1568        input_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_7 (Insta (None, 64, 64, 32)   2           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   32832       instance_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 32, 32, 64)   2           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  131200      instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 16, 16, 128)  2           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    524544      instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 8, 8, 256)    2           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  524416      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 16, 16, 128)  2           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           instance_normalization_11[0][0]
#                                                                  instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 64)   262208      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 32, 32, 64)   2           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           instance_normalization_12[0][0]
#                                                                  instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 32)   65568       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 64, 64, 32)   2           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           instance_normalization_13[0][0]
#                                                                  instance_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 3)  3075        up_sampling2d_4[0][0]
# ==================================================================================================
# Total params: 1,545,425
# Trainable params: 1,545,425
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Input images from both domains
img_A = Input(shape=img_shape)
img_B = Input(shape=img_shape)

# %%
 # Translate images to the other domain
fake_B = g_AB(img_A)
fake_A = g_BA(img_B)

# %%
 # Translate images back to original domain
reconstr_A = g_BA(fake_B)
reconstr_B = g_AB(fake_A)

# %%
#Identity mapping of images
img_A_id = g_BA(img_A)
img_B_id = g_AB(img_B)

# %%
# For the combined model we will only train the generators
d_A.trainable = False
d_B.trainable = False

# %%
# Discriminators determines validity of translated images
valid_A = d_A(fake_A)
valid_B = d_B(fake_B)

# %% [markdown]
# <a class="anchor" id="7"></a>
# ### Loss Function
# we have two generators and two discriminators. We need to design the loss function in a way which accomplishes our goal. The loss function can be seen having four parts:
#
# 1) Discriminator must approve all the original images of the corresponding categories.
#
# 2) Discriminator must reject all the images which are generated by corresponding Generators to fool them.
#
# 3) Generators must make the discriminators approve all the generated images, so as to fool them.
#
# 4) The generated image must retain the property of original image, so if we generate a fake image using a generator say  GeneratorA→B  then we must be able to get back to original image using the another generator  GeneratorB→A  - it must satisfy cyclic-consistency.

# %%
# Combined model trains generators to fool discriminators
combined = Model(inputs=[img_A, img_B],outputs=[ valid_A, valid_B,reconstr_A, reconstr_B,
                                        img_A_id, img_B_id ])

# %%
combined.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# model_4 (Model)                 (None, 128, 128, 3)  1545425     input_6[0][0]
#                                                                  model_3[1][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 128, 128, 3)  1545425     input_5[0][0]
#                                                                  model_4[1][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 8, 8, 1)      2764743     model_4[1][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 8, 8, 1)      2764743     model_3[1][0]
# ==================================================================================================
# Total params: 8,620,336
# Trainable params: 3,090,850
# Non-trainable params: 5,529,486
# __________________________________________________________________________________________________

# %% [markdown]
# #### Combined loss
# Generator should eventually be able to fool the discriminator about the authencity of it's generated images. This can done if the recommendation by discriminator for the generated images is as close to 1 as possible. So generator would like to minimize  (DiscriminatorB(GeneratorA→B(a))−1)2  So the loss is:

# %%
combined.compile(loss=['mse', 'mse','mae', 'mae','mae', 'mae'],
                            loss_weights=[  1, 1,lambda_cycle, lambda_cycle,lambda_id, lambda_id ],
                            optimizer=optimizer)

# %%
imageSize = 128
from PIL import Image
from IPython.display import display
def showX(X, rows=1):
    assert X.shape[0]%rows == 0
    int_X = ( (X+1)/2*255).clip(0,255).astype('uint8')    
    int_X = int_X.reshape(-1,imageSize,imageSize, 3)
    int_X = int_X.reshape(rows, -1, imageSize,imageSize,3).swapaxes(1,2).reshape(rows*imageSize,-1, 3)
    display(Image.fromarray(int_X))

# %%
def sample_images(epoch, batch_i):
    os.makedirs('images/%s' % dataset_name, exist_ok=True)
    r, c = 2, 3

    imgs_A = data_loader.load_data(domain="A", batch_size=1, is_testing=True)
    imgs_B = data_loader.load_data(domain="B", batch_size=1, is_testing=True)

    # Translate images to the other domain
    fake_B = g_AB.predict(imgs_A)
    fake_A = g_BA.predict(imgs_B)
   
    # Translate back to original domain
    reconstr_A = g_BA.predict(fake_B)
    reconstr_B = g_AB.predict(fake_A)

    gen_imgs = np.concatenate([imgs_A, fake_B, reconstr_A, imgs_B, fake_A, reconstr_B])

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    # Show/plot on terminal the results of Both the Networks A->B & B->A
    titles = ['Original', 'Translated', 'Reconstructed']
    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt])
            axs[i, j].set_title(titles[j])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("images/%s/%d_%d.png" % (dataset_name, epoch, batch_i))
    plt.close()

# %%
def train(epochs, batch_size=1, sample_interval=200):

    print("Train method")
    print("epochs is ",epochs)
    start_time = datetime.datetime.now()

    # Adversarial loss ground truths
    valid = np.ones((batch_size,) + disc_patch)
    fake = np.zeros((batch_size,) + disc_patch)

    for epoch in range(epochs):
        print("Inside 1st for-loop")
        dataloader = DataLoader(dataset_name,img_res=(128, 128))  #(self, dataset_name, img_res=(128, 128))
        for batch_i, (imgs_A, imgs_B) in enumerate(dataloader.load_batch(batch_size)):

            # ----------------------
            #  Train Discriminators
            # ----------------------

            print("Inside 2nd for loop")
            # Translate images to opposite domain
            fake_B = g_AB.predict(imgs_A)
            fake_A = g_BA.predict(imgs_B)

            # Train the discriminators (original images = real / translated = Fake)
            dA_loss_real = d_A.train_on_batch(imgs_A, valid)
            dA_loss_fake = d_A.train_on_batch(fake_A, fake)
            dA_loss = 0.5 * np.add(dA_loss_real, dA_loss_fake)

            dB_loss_real = d_B.train_on_batch(imgs_B, valid)
            dB_loss_fake = d_B.train_on_batch(fake_B, fake)
            dB_loss = 0.5 * np.add(dB_loss_real, dB_loss_fake)

            # Total disciminator loss
            d_loss = 0.5 * np.add(dA_loss, dB_loss)


            # ------------------
            #  Train Generators
            # ------------------

            # Train the generators
            g_loss = combined.train_on_batch([imgs_A, imgs_B],
                                                        [valid, valid,
                                                        imgs_A, imgs_B,
                                                        imgs_A, imgs_B])

            elapsed_time = datetime.datetime.now() - start_time

            # Plot the progress
            print ("[Epoch %d/%d] [Batch %d/%d] [D loss: %f, acc: %3d%%] [G loss: %05f, adv: %05f, recon: %05f, id: %05f] time: %s " \
                                                                        % ( epoch, epochs,
                                                                            batch_i, dataloader.n_batches,
                                                                            d_loss[0], 100*d_loss[1],
                                                                            g_loss[0],
                                                                            np.mean(g_loss[1:3]),
                                                                            np.mean(g_loss[3:5]),
                                                                            np.mean(g_loss[5:6]),
                                                                            elapsed_time))

            # If at save interval => save generated image samples
            if batch_i % sample_interval == 0:
                sample_images(epoch, batch_i)
                d_A.save('d_A_model.h5')
                d_A.save_weights('d_A_save_weights.h5')
                d_B.save('d_B_model.h5')
                d_B.save_weights('d_B_save_weights.h5')
                g_AB.save('g_AB_model.h5')
                g_AB.save_weights('g_AB_save_weights.h5')
                g_BA.save('g_BA_model.h5')
                g_BA.save_weights('g_BA_save_weights.h5')
                combined.save('combined_model.h5')
                combined.save_weights('combined_save_weights.h5')

# %%
train(25, batch_size=1, sample_interval=200)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:79: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# W0826 14:25:56.424551 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0826 14:25:56.427670 139795172575104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# Train method
# epochs is  25
# Inside 1st for-loop
# Inside the constructor
# dataset_name is  apple2orange
# Inside load_batch() method
# Inside 2nd for loop
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# [Epoch 0/25] [Batch 0/995] [D loss: 19.799665, acc:  17%] [G loss: 87.492065, adv: 35.015812, recon: 0.788032, id: 1.059327] time: 0:00:24.974429
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:79: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Inside 2nd for loop
# [Epoch 0/25] [Batch 1/995] [D loss: 34.786201, acc:   7%] [G loss: 66.032501, adv: 21.621555, recon: 1.048660, id: 0.819466] time: 0:00:40.448495
# Inside 2nd for loop
# [Epoch 0/25] [Batch 2/995] [D loss: 32.086899, acc:   7%] [G loss: 29.483713, adv: 4.332979, recon: 0.946496, id: 0.804511] time: 0:00:42.990078
# Inside 2nd for loop
# [Epoch 0/25] [Batch 3/995] [D loss: 8.734655, acc:  18%] [G loss: 25.383871, adv: 4.896257, recon: 0.704129, id: 0.775823] time: 0:00:45.477714
# Inside 2nd for loop
# [Epoch 0/25] [Batch 4/995] [D loss: 4.185279, acc:  17%] [G loss: 20.382942, adv: 1.159224, recon: 0.796739, id: 1.461490] time: 0:00:48.000003
# Inside 2nd for loop
# [Epoch 0/25] [Batch 5/995] [D loss: 3.221765, acc:  22%] [G loss: 14.737690, adv: 0.727381, recon: 0.581710, id: 0.925640] time: 0:00:50.498453
# Inside 2nd for loop
# [Epoch 0/25] [Batch 6/995] [D loss: 0.606180, acc:  56%] [G loss: 16.249496, adv: 1.177178, recon: 0.617824, id: 0.722227] time: 0:00:53.020901
# Inside 2nd for loop
# [Epoch 0/25] [Batch 7/995] [D loss: 1.857099, acc:   8%] [G loss: 13.565500, adv: 1.175683, recon: 0.481338, id: 0.777285] time: 0:00:55.556853
# Inside 2nd for loop
# [Epoch 0/25] [Batch 8/995] [D loss: 0.338653, acc:  50%] [G loss: 10.750866, adv: 1.101138, recon: 0.365096, id: 0.638474] time: 0:00:58.115141
# Inside 2nd for loop
# [Epoch 0/25] [Batch 9/995] [D loss: 0.551958, acc:  40%] [G loss: 9.363986, adv: 0.569430, recon: 0.353928, id: 0.650501] time: 0:01:00.616156
# Inside 2nd for loop
# [Epoch 0/25] [Batch 10/995] [D loss: 0.552806, acc:  45%] [G loss: 11.580764, adv: 0.961659, recon: 0.381834, id: 1.295875] time: 0:01:03.226582
# Inside 2nd for loop
# [Epoch 0/25] [Batch 11/995] [D loss: 0.607693, acc:  42%] [G loss: 13.457585, adv: 0.982919, recon: 0.465277, id: 1.233007] time: 0:01:05.726504
# Inside 2nd for loop
# [Epoch 0/25] [Batch 12/995] [D loss: 0.470603, acc:  56%] [G loss: 11.503069, adv: 0.796855, recon: 0.413306, id: 0.769556] time: 0:01:08.210258
# Inside 2nd for loop
# [Epoch 0/25] [Batch 13/995] [D loss: 0.461747, acc:  38%] [G loss: 10.326477, adv: 0.706589, recon: 0.360715, id: 0.797566] time: 0:01:10.706565
# Inside 2nd for loop
# [Epoch 0/25] [Batch 14/995] [D loss: 0.672888, acc:  15%] [G loss: 8.509650, adv: 0.631513, recon: 0.286034, id: 0.613336] time: 0:01:13.216791
# Inside 2nd for loop
# [Epoch 0/25] [Batch 15/995] [D loss: 0.270600, acc:  65%] [G loss: 8.283444, adv: 0.984311, recon: 0.224151, id: 0.977669] time: 0:01:15.742542
# Inside 2nd for loop
# [Epoch 0/25] [Batch 16/995] [D loss: 0.668567, acc:  55%] [G loss: 11.996722, adv: 0.826606, recon: 0.427515, id: 0.633554] time: 0:01:18.244823
# Inside 2nd for loop
# [Epoch 0/25] [Batch 17/995] [D loss: 0.911371, acc:  43%] [G loss: 9.478810, adv: 1.035891, recon: 0.264071, id: 1.520430] time: 0:01:20.751766
# Inside 2nd for loop
# [Epoch 0/25] [Batch 18/995] [D loss: 0.812518, acc:  33%] [G loss: 11.044744, adv: 0.876672, recon: 0.393539, id: 0.646494] time: 0:01:23.248910
# Inside 2nd for loop
# [Epoch 0/25] [Batch 19/995] [D loss: 0.576518, acc:  32%] [G loss: 10.662184, adv: 0.754799, recon: 0.393705, id: 0.519293] time: 0:01:25.826522
# Inside 2nd for loop
# [Epoch 0/25] [Batch 20/995] [D loss: 0.875610, acc:  29%] [G loss: 11.386559, adv: 0.624689, recon: 0.423140, id: 0.903029] time: 0:01:28.377100
# Inside 2nd for loop
# [Epoch 0/25] [Batch 21/995] [D loss: 0.543919, acc:  25%] [G loss: 11.127122, adv: 0.612151, recon: 0.428476, id: 0.658422] time: 0:01:30.905752
# Inside 2nd for loop
# [Epoch 0/25] [Batch 22/995] [D loss: 0.401945, acc:  42%] [G loss: 8.231989, adv: 0.776059, recon: 0.274399, id: 0.484149] time: 0:01:33.444729
# Inside 2nd for loop
# [Epoch 0/25] [Batch 23/995] [D loss: 0.215953, acc:  72%] [G loss: 11.704157, adv: 0.956149, recon: 0.400226, id: 0.636238] time: 0:01:36.029314
# Inside 2nd for loop
# [Epoch 0/25] [Batch 24/995] [D loss: 1.051695, acc:  14%] [G loss: 8.937315, adv: 0.688428, recon: 0.310385, id: 0.688273] time: 0:01:38.558642
# Inside 2nd for loop
# [Epoch 0/25] [Batch 25/995] [D loss: 1.134353, acc:  63%] [G loss: 10.380721, adv: 1.072908, recon: 0.329375, id: 0.872259] time: 0:01:41.080385
# Inside 2nd for loop
# [Epoch 0/25] [Batch 26/995] [D loss: 0.887804, acc:  24%] [G loss: 8.516805, adv: 0.710341, recon: 0.293344, id: 0.535926] time: 0:01:43.615055
# Inside 2nd for loop
# [Epoch 0/25] [Batch 27/995] [D loss: 1.908457, acc:  23%] [G loss: 11.031853, adv: 1.865961, recon: 0.301712, id: 0.808782] time: 0:01:46.152690
# Inside 2nd for loop
# [Epoch 0/25] [Batch 28/995] [D loss: 1.181079, acc:  27%] [G loss: 8.378931, adv: 0.369416, recon: 0.313476, id: 0.615648] time: 0:01:48.708943
# Inside 2nd for loop
# [Epoch 0/25] [Batch 29/995] [D loss: 0.315037, acc:  64%] [G loss: 11.440260, adv: 1.257954, recon: 0.362951, id: 0.783687] time: 0:01:51.225677
# Inside 2nd for loop
# [Epoch 0/25] [Batch 30/995] [D loss: 0.406630, acc:  48%] [G loss: 9.967101, adv: 0.857513, recon: 0.345215, id: 0.597567] time: 0:01:53.759618
# Inside 2nd for loop
# [Epoch 0/25] [Batch 31/995] [D loss: 0.407105, acc:  44%] [G loss: 10.055871, adv: 0.584287, recon: 0.362030, id: 0.812580] time: 0:01:56.276385
# Inside 2nd for loop
# [Epoch 0/25] [Batch 32/995] [D loss: 0.264515, acc:  61%] [G loss: 9.444375, adv: 1.184326, recon: 0.281145, id: 0.529855] time: 0:01:58.770867
# Inside 2nd for loop
# [Epoch 0/25] [Batch 33/995] [D loss: 0.506698, acc:  57%] [G loss: 13.753827, adv: 0.643833, recon: 0.562583, id: 0.716458] time: 0:02:01.274959
# Inside 2nd for loop
# [Epoch 0/25] [Batch 34/995] [D loss: 0.450386, acc:  43%] [G loss: 8.820950, adv: 0.668154, recon: 0.314974, id: 0.580163] time: 0:02:03.793214
# Inside 2nd for loop
# [Epoch 0/25] [Batch 35/995] [D loss: 0.202316, acc:  72%] [G loss: 8.989048, adv: 0.847064, recon: 0.286104, id: 0.822667] time: 0:02:06.315271
# Inside 2nd for loop
# [Epoch 0/25] [Batch 36/995] [D loss: 0.668978, acc:  22%] [G loss: 6.983314, adv: 0.579995, recon: 0.218983, id: 0.747211] time: 0:02:08.796124
# Inside 2nd for loop
# [Epoch 0/25] [Batch 37/995] [D loss: 0.323708, acc:  46%] [G loss: 10.614754, adv: 0.784071, recon: 0.381669, id: 0.586783] time: 0:02:11.302889
# Inside 2nd for loop
# [Epoch 0/25] [Batch 38/995] [D loss: 0.218843, acc:  76%] [G loss: 10.722744, adv: 0.848295, recon: 0.377990, id: 0.696476] time: 0:02:13.814153
# Inside 2nd for loop
# [Epoch 0/25] [Batch 39/995] [D loss: 0.796357, acc:  23%] [G loss: 7.574340, adv: 0.639197, recon: 0.261236, id: 0.388386] time: 0:02:16.294437
# Inside 2nd for loop
# [Epoch 0/25] [Batch 40/995] [D loss: 0.419758, acc:  39%] [G loss: 10.031385, adv: 0.687835, recon: 0.372287, id: 0.674404] time: 0:02:18.795353
# Inside 2nd for loop
# [Epoch 0/25] [Batch 41/995] [D loss: 0.186297, acc:  71%] [G loss: 7.060834, adv: 0.772026, recon: 0.208334, id: 0.588797] time: 0:02:21.269923
# Inside 2nd for loop
# [Epoch 0/25] [Batch 42/995] [D loss: 0.312921, acc:  51%] [G loss: 8.200574, adv: 0.693764, recon: 0.277585, id: 0.559071] time: 0:02:23.737959
# Inside 2nd for loop
# [Epoch 0/25] [Batch 43/995] [D loss: 0.227126, acc:  62%] [G loss: 9.225431, adv: 0.779151, recon: 0.313606, id: 0.553303] time: 0:02:26.293639
# Inside 2nd for loop
# [Epoch 0/25] [Batch 44/995] [D loss: 0.293205, acc:  61%] [G loss: 8.963258, adv: 0.797664, recon: 0.302305, id: 0.672318] time: 0:02:28.805786
# Inside 2nd for loop
# [Epoch 0/25] [Batch 45/995] [D loss: 0.485297, acc:  56%] [G loss: 7.606510, adv: 1.076872, recon: 0.208335, id: 0.645933] time: 0:02:31.298948
# Inside 2nd for loop
# [Epoch 0/25] [Batch 46/995] [D loss: 0.660728, acc:  31%] [G loss: 7.529891, adv: 0.797766, recon: 0.248610, id: 0.543581] time: 0:02:33.815245
# Inside 2nd for loop
# [Epoch 0/25] [Batch 47/995] [D loss: 0.598724, acc:  51%] [G loss: 8.137892, adv: 0.837853, recon: 0.260348, id: 0.769411] time: 0:02:36.310929
# Inside 2nd for loop
# [Epoch 0/25] [Batch 48/995] [D loss: 0.776614, acc:  14%] [G loss: 9.109801, adv: 0.540186, recon: 0.339648, id: 0.678586] time: 0:02:38.831256
# Inside 2nd for loop
# [Epoch 0/25] [Batch 49/995] [D loss: 0.476805, acc:  38%] [G loss: 8.814758, adv: 0.673198, recon: 0.318603, id: 0.496178] time: 0:02:41.301154
# Inside 2nd for loop
# [Epoch 0/25] [Batch 50/995] [D loss: 0.822761, acc:   2%] [G loss: 8.565304, adv: 0.568836, recon: 0.298811, id: 0.646375] time: 0:02:43.785599
# Inside 2nd for loop
# [Epoch 0/25] [Batch 51/995] [D loss: 0.479198, acc:  23%] [G loss: 8.778280, adv: 0.590632, recon: 0.306621, id: 0.820869] time: 0:02:46.289570
# Inside 2nd for loop
# [Epoch 0/25] [Batch 52/995] [D loss: 0.303927, acc:  48%] [G loss: 8.855055, adv: 0.724406, recon: 0.301648, id: 0.688575] time: 0:02:48.809144
# Inside 2nd for loop
# [Epoch 0/25] [Batch 53/995] [D loss: 0.385331, acc:  42%] [G loss: 7.260109, adv: 0.764227, recon: 0.215750, id: 0.663798] time: 0:02:51.340692
# Inside 2nd for loop
# [Epoch 0/25] [Batch 54/995] [D loss: 0.600644, acc:  27%] [G loss: 6.541473, adv: 0.587551, recon: 0.214215, id: 0.634424] time: 0:02:53.813066
# Inside 2nd for loop
# [Epoch 0/25] [Batch 55/995] [D loss: 0.526293, acc:  19%] [G loss: 7.849369, adv: 0.611709, recon: 0.261516, id: 0.676996] time: 0:02:56.283109
# Inside 2nd for loop
# [Epoch 0/25] [Batch 56/995] [D loss: 0.445305, acc:  19%] [G loss: 6.728645, adv: 0.715892, recon: 0.175170, id: 0.906777] time: 0:02:58.820573
# Inside 2nd for loop
# [Epoch 0/25] [Batch 57/995] [D loss: 0.255966, acc:  56%] [G loss: 7.103753, adv: 0.720807, recon: 0.200801, id: 0.722216] time: 0:03:01.346249
# Inside 2nd for loop
# [Epoch 0/25] [Batch 58/995] [D loss: 0.549613, acc:  16%] [G loss: 9.237434, adv: 0.599533, recon: 0.320627, id: 0.742634] time: 0:03:03.883504
# Inside 2nd for loop
# [Epoch 0/25] [Batch 59/995] [D loss: 0.242526, acc:  62%] [G loss: 6.599158, adv: 0.851665, recon: 0.160692, id: 0.855329] time: 0:03:06.415484
# Inside 2nd for loop
# [Epoch 0/25] [Batch 60/995] [D loss: 0.345994, acc:  52%] [G loss: 6.716788, adv: 0.784697, recon: 0.193286, id: 0.541732] time: 0:03:08.958705
# Inside 2nd for loop
# [Epoch 0/25] [Batch 61/995] [D loss: 0.387680, acc:  40%] [G loss: 7.066381, adv: 0.780463, recon: 0.200359, id: 0.609492] time: 0:03:11.480832
# Inside 2nd for loop
# [Epoch 0/25] [Batch 62/995] [D loss: 0.510567, acc:  16%] [G loss: 7.020784, adv: 0.593036, recon: 0.215629, id: 0.710200] time: 0:03:13.991375
# Inside 2nd for loop
# [Epoch 0/25] [Batch 63/995] [D loss: 0.532231, acc:  46%] [G loss: 7.971195, adv: 1.038442, recon: 0.209267, id: 0.749121] time: 0:03:16.509166
# Inside 2nd for loop
# [Epoch 0/25] [Batch 64/995] [D loss: 0.825992, acc:  36%] [G loss: 10.149145, adv: 1.002977, recon: 0.336919, id: 0.619753] time: 0:03:19.017555
# Inside 2nd for loop
# [Epoch 0/25] [Batch 65/995] [D loss: 0.634357, acc:  42%] [G loss: 7.866445, adv: 0.611985, recon: 0.256348, id: 0.648599] time: 0:03:21.525909
# Inside 2nd for loop
# [Epoch 0/25] [Batch 66/995] [D loss: 0.851942, acc:  26%] [G loss: 8.381525, adv: 0.572395, recon: 0.286904, id: 0.681665] time: 0:03:24.049339
# Inside 2nd for loop
# [Epoch 0/25] [Batch 67/995] [D loss: 0.661067, acc:  26%] [G loss: 7.245310, adv: 0.638845, recon: 0.241871, id: 0.385458] time: 0:03:26.612951
# Inside 2nd for loop
# [Epoch 0/25] [Batch 68/995] [D loss: 0.384473, acc:  35%] [G loss: 8.699334, adv: 0.671326, recon: 0.297679, id: 0.863811] time: 0:03:29.184980
# Inside 2nd for loop
# [Epoch 0/25] [Batch 69/995] [D loss: 0.592046, acc:   6%] [G loss: 7.388598, adv: 0.484976, recon: 0.260305, id: 0.622841] time: 0:03:31.714191
# Inside 2nd for loop
# [Epoch 0/25] [Batch 70/995] [D loss: 0.428922, acc:  24%] [G loss: 8.142481, adv: 0.552405, recon: 0.287469, id: 0.703354] time: 0:03:34.276788
# Inside 2nd for loop
# [Epoch 0/25] [Batch 71/995] [D loss: 0.227902, acc:  58%] [G loss: 6.296089, adv: 0.732088, recon: 0.181855, id: 0.745003] time: 0:03:36.848383
# Inside 2nd for loop
# [Epoch 0/25] [Batch 72/995] [D loss: 0.440107, acc:  28%] [G loss: 6.233935, adv: 0.626345, recon: 0.197043, id: 0.576846] time: 0:03:39.389009
# Inside 2nd for loop
# [Epoch 0/25] [Batch 73/995] [D loss: 0.378769, acc:  24%] [G loss: 7.754174, adv: 0.642921, recon: 0.275318, id: 0.484630] time: 0:03:41.955572
# Inside 2nd for loop
# [Epoch 0/25] [Batch 74/995] [D loss: 0.410707, acc:  39%] [G loss: 6.788683, adv: 0.606168, recon: 0.214936, id: 0.618312] time: 0:03:44.473836
# Inside 2nd for loop
# [Epoch 0/25] [Batch 75/995] [D loss: 0.141799, acc:  78%] [G loss: 6.650364, adv: 1.035797, recon: 0.147433, id: 0.772694] time: 0:03:46.964818
# Inside 2nd for loop
# [Epoch 0/25] [Batch 76/995] [D loss: 0.469693, acc:  30%] [G loss: 7.620367, adv: 0.646747, recon: 0.251010, id: 0.620924] time: 0:03:49.455636
# Inside 2nd for loop
# [Epoch 0/25] [Batch 77/995] [D loss: 0.208007, acc:  76%] [G loss: 8.046984, adv: 0.856278, recon: 0.236748, id: 0.550003] time: 0:03:51.998669
# Inside 2nd for loop
# [Epoch 0/25] [Batch 78/995] [D loss: 0.178203, acc:  71%] [G loss: 9.147216, adv: 0.786970, recon: 0.310815, id: 0.717101] time: 0:03:54.479828
# Inside 2nd for loop
# [Epoch 0/25] [Batch 79/995] [D loss: 0.752253, acc:  14%] [G loss: 7.584615, adv: 0.644432, recon: 0.253391, id: 0.567270] time: 0:03:56.995414
# Inside 2nd for loop
# [Epoch 0/25] [Batch 80/995] [D loss: 0.384870, acc:  35%] [G loss: 7.205805, adv: 0.670832, recon: 0.232487, id: 0.455783] time: 0:03:59.492315
# Inside 2nd for loop
# [Epoch 0/25] [Batch 81/995] [D loss: 0.390595, acc:  39%] [G loss: 7.947514, adv: 0.648056, recon: 0.257330, id: 0.622120] time: 0:04:02.027421
# Inside 2nd for loop
# [Epoch 0/25] [Batch 82/995] [D loss: 0.180666, acc:  72%] [G loss: 7.256805, adv: 0.887419, recon: 0.207867, id: 0.578029] time: 0:04:04.537504
# Inside 2nd for loop
# [Epoch 0/25] [Batch 83/995] [D loss: 0.310740, acc:  46%] [G loss: 8.344124, adv: 0.711510, recon: 0.275643, id: 0.675364] time: 0:04:07.043287
# Inside 2nd for loop
# [Epoch 0/25] [Batch 84/995] [D loss: 0.283236, acc:  44%] [G loss: 7.833911, adv: 0.735377, recon: 0.258258, id: 0.479958] time: 0:04:09.560427
# Inside 2nd for loop
# [Epoch 0/25] [Batch 85/995] [D loss: 0.428930, acc:  10%] [G loss: 6.542511, adv: 0.647612, recon: 0.206905, id: 0.461388] time: 0:04:12.092057
# Inside 2nd for loop
# [Epoch 0/25] [Batch 86/995] [D loss: 0.148486, acc:  76%] [G loss: 7.077743, adv: 0.998173, recon: 0.191268, id: 0.679847] time: 0:04:14.610623
# Inside 2nd for loop
# [Epoch 0/25] [Batch 87/995] [D loss: 0.499916, acc:  31%] [G loss: 7.716707, adv: 0.818089, recon: 0.243791, id: 0.436995] time: 0:04:17.147362
# Inside 2nd for loop
# [Epoch 0/25] [Batch 88/995] [D loss: 0.530418, acc:  19%] [G loss: 8.346331, adv: 0.607106, recon: 0.299499, id: 0.543632] time: 0:04:19.675944
# Inside 2nd for loop
# [Epoch 0/25] [Batch 89/995] [D loss: 0.813582, acc:   9%] [G loss: 7.572248, adv: 0.577897, recon: 0.245993, id: 0.672728] time: 0:04:22.242083
# Inside 2nd for loop
# [Epoch 0/25] [Batch 90/995] [D loss: 0.394073, acc:  28%] [G loss: 7.935764, adv: 0.631635, recon: 0.289345, id: 0.372190] time: 0:04:24.759394
# Inside 2nd for loop
# [Epoch 0/25] [Batch 91/995] [D loss: 0.330759, acc:  44%] [G loss: 6.642208, adv: 0.681079, recon: 0.200456, id: 0.502947] time: 0:04:27.287326
# Inside 2nd for loop
# [Epoch 0/25] [Batch 92/995] [D loss: 0.580079, acc:  25%] [G loss: 6.182707, adv: 0.604217, recon: 0.191170, id: 0.770085] time: 0:04:29.804914
# Inside 2nd for loop
# [Epoch 0/25] [Batch 93/995] [D loss: 0.274302, acc:  60%] [G loss: 8.404402, adv: 0.832617, recon: 0.260142, id: 0.736607] time: 0:04:32.316277
# Inside 2nd for loop
# [Epoch 0/25] [Batch 94/995] [D loss: 0.520824, acc:  19%] [G loss: 7.917265, adv: 0.608475, recon: 0.268292, id: 0.592731] time: 0:04:34.813247
# Inside 2nd for loop
# [Epoch 0/25] [Batch 95/995] [D loss: 0.140965, acc:  82%] [G loss: 7.464167, adv: 0.890452, recon: 0.220145, id: 0.387942] time: 0:04:37.279055
# Inside 2nd for loop
# [Epoch 0/25] [Batch 96/995] [D loss: 0.253740, acc:  61%] [G loss: 5.462583, adv: 0.627851, recon: 0.171352, id: 0.371879] time: 0:04:39.747311
# Inside 2nd for loop
# [Epoch 0/25] [Batch 97/995] [D loss: 0.371395, acc:  48%] [G loss: 10.472348, adv: 0.738544, recon: 0.373159, id: 0.562476] time: 0:04:42.235609
# Inside 2nd for loop
# [Epoch 0/25] [Batch 98/995] [D loss: 0.143218, acc:  79%] [G loss: 6.956574, adv: 0.902841, recon: 0.180102, id: 0.497181] time: 0:04:44.706178
# Inside 2nd for loop
# [Epoch 0/25] [Batch 99/995] [D loss: 0.112329, acc:  85%] [G loss: 8.055969, adv: 0.862525, recon: 0.236818, id: 0.594383] time: 0:04:47.162520
# Inside 2nd for loop
# [Epoch 0/25] [Batch 100/995] [D loss: 0.618032, acc:  29%] [G loss: 6.719957, adv: 0.613054, recon: 0.208801, id: 0.640379] time: 0:04:49.626399
# Inside 2nd for loop
# [Epoch 0/25] [Batch 101/995] [D loss: 0.327543, acc:  53%] [G loss: 7.000486, adv: 0.713473, recon: 0.204654, id: 0.680867] time: 0:04:52.084168
# Inside 2nd for loop
# [Epoch 0/25] [Batch 102/995] [D loss: 0.281674, acc:  59%] [G loss: 4.838600, adv: 0.694425, recon: 0.109216, id: 0.555123] time: 0:04:54.576369
# Inside 2nd for loop
# [Epoch 0/25] [Batch 103/995] [D loss: 0.402810, acc:  32%] [G loss: 6.933446, adv: 0.698224, recon: 0.217618, id: 0.557070] time: 0:04:57.076431
# Inside 2nd for loop
# [Epoch 0/25] [Batch 104/995] [D loss: 0.174658, acc:  76%] [G loss: 7.145126, adv: 1.061193, recon: 0.182223, id: 0.458580] time: 0:04:59.549310
# Inside 2nd for loop
# [Epoch 0/25] [Batch 105/995] [D loss: 0.484727, acc:  32%] [G loss: 6.182326, adv: 0.590396, recon: 0.178941, id: 0.508850] time: 0:05:02.011094
# Inside 2nd for loop
# [Epoch 0/25] [Batch 106/995] [D loss: 0.142549, acc:  78%] [G loss: 9.314224, adv: 1.192668, recon: 0.280193, id: 0.500195] time: 0:05:04.488659
# Inside 2nd for loop
# [Epoch 0/25] [Batch 107/995] [D loss: 0.791174, acc:   6%] [G loss: 6.997675, adv: 0.387720, recon: 0.237529, id: 0.623040] time: 0:05:06.984883
# Inside 2nd for loop
# [Epoch 0/25] [Batch 108/995] [D loss: 0.240827, acc:  53%] [G loss: 8.178924, adv: 0.801323, recon: 0.271213, id: 0.481349] time: 0:05:09.518008
# Inside 2nd for loop
# [Epoch 0/25] [Batch 109/995] [D loss: 0.379099, acc:  30%] [G loss: 6.841793, adv: 0.615314, recon: 0.218803, id: 0.511481] time: 0:05:12.053454
# Inside 2nd for loop
# [Epoch 0/25] [Batch 110/995] [D loss: 0.600799, acc:   6%] [G loss: 9.240575, adv: 0.542405, recon: 0.351537, id: 0.482575] time: 0:05:14.681363
# Inside 2nd for loop
# [Epoch 0/25] [Batch 111/995] [D loss: 0.460490, acc:   5%] [G loss: 7.215995, adv: 0.594376, recon: 0.239234, id: 0.705100] time: 0:05:17.236487
# Inside 2nd for loop
# [Epoch 0/25] [Batch 112/995] [D loss: 0.141755, acc:  80%] [G loss: 7.993491, adv: 1.041179, recon: 0.241842, id: 0.368452] time: 0:05:19.751575
# Inside 2nd for loop
# [Epoch 0/25] [Batch 113/995] [D loss: 0.227937, acc:  73%] [G loss: 7.322245, adv: 0.696002, recon: 0.223362, id: 0.394943] time: 0:05:22.264637
# Inside 2nd for loop
# [Epoch 0/25] [Batch 114/995] [D loss: 0.088570, acc:  93%] [G loss: 6.561036, adv: 1.020648, recon: 0.173064, id: 0.366213] time: 0:05:24.813343
# Inside 2nd for loop
# [Epoch 0/25] [Batch 115/995] [D loss: 0.422442, acc:  32%] [G loss: 6.685821, adv: 0.576151, recon: 0.215941, id: 0.611719] time: 0:05:27.336644
# Inside 2nd for loop
# [Epoch 0/25] [Batch 116/995] [D loss: 0.848704, acc:  17%] [G loss: 8.533017, adv: 0.849072, recon: 0.262342, id: 0.844810] time: 0:05:29.862541
# Inside 2nd for loop
# [Epoch 0/25] [Batch 117/995] [D loss: 0.472983, acc:  48%] [G loss: 7.023173, adv: 0.595479, recon: 0.231133, id: 0.392151] time: 0:05:32.364537
# Inside 2nd for loop
# [Epoch 0/25] [Batch 118/995] [D loss: 0.246414, acc:  58%] [G loss: 5.486100, adv: 0.711131, recon: 0.151164, id: 0.509502] time: 0:05:34.901882
# Inside 2nd for loop
# [Epoch 0/25] [Batch 119/995] [D loss: 0.187984, acc:  74%] [G loss: 8.251573, adv: 0.998488, recon: 0.242364, id: 0.495766] time: 0:05:37.429856
# Inside 2nd for loop
# [Epoch 0/25] [Batch 120/995] [D loss: 0.489182, acc:  26%] [G loss: 7.469963, adv: 0.508842, recon: 0.265635, id: 0.589811] time: 0:05:39.947175
# Inside 2nd for loop
# [Epoch 0/25] [Batch 121/995] [D loss: 0.373241, acc:  37%] [G loss: 7.856868, adv: 0.646943, recon: 0.259326, id: 0.682851] time: 0:05:42.479442
# Inside 2nd for loop
# [Epoch 0/25] [Batch 122/995] [D loss: 0.207646, acc:  73%] [G loss: 7.036017, adv: 0.822732, recon: 0.222579, id: 0.502681] time: 0:05:45.002821
# Inside 2nd for loop
# [Epoch 0/25] [Batch 123/995] [D loss: 0.203321, acc:  76%] [G loss: 7.967838, adv: 0.847862, recon: 0.256993, id: 0.458366] time: 0:05:47.518012
# Inside 2nd for loop
# [Epoch 0/25] [Batch 124/995] [D loss: 0.374661, acc:  51%] [G loss: 7.083574, adv: 1.041837, recon: 0.180515, id: 0.463962] time: 0:05:50.031755
# Inside 2nd for loop
# [Epoch 0/25] [Batch 125/995] [D loss: 0.216154, acc:  66%] [G loss: 4.940422, adv: 0.691090, recon: 0.128858, id: 0.448921] time: 0:05:52.553224
# Inside 2nd for loop
# [Epoch 0/25] [Batch 126/995] [D loss: 0.238599, acc:  58%] [G loss: 5.235219, adv: 0.698600, recon: 0.130749, id: 0.668292] time: 0:05:55.062871
# Inside 2nd for loop
# [Epoch 0/25] [Batch 127/995] [D loss: 0.175712, acc:  75%] [G loss: 8.162217, adv: 0.779397, recon: 0.272569, id: 0.613506] time: 0:05:57.591531
# Inside 2nd for loop
# [Epoch 0/25] [Batch 128/995] [D loss: 0.345907, acc:  51%] [G loss: 10.871818, adv: 1.043059, recon: 0.362156, id: 0.490046] time: 0:06:00.088860
# Inside 2nd for loop
# [Epoch 0/25] [Batch 129/995] [D loss: 0.641808, acc:  33%] [G loss: 6.634043, adv: 0.540432, recon: 0.210996, id: 0.657173] time: 0:06:02.581592
# Inside 2nd for loop
# [Epoch 0/25] [Batch 130/995] [D loss: 0.263228, acc:  68%] [G loss: 6.326710, adv: 0.835644, recon: 0.178548, id: 0.481933] time: 0:06:05.089378
# Inside 2nd for loop
# [Epoch 0/25] [Batch 131/995] [D loss: 1.028263, acc:  33%] [G loss: 8.378584, adv: 0.631037, recon: 0.263406, id: 0.866186] time: 0:06:07.675377
# Inside 2nd for loop
# [Epoch 0/25] [Batch 132/995] [D loss: 0.912169, acc:  13%] [G loss: 7.617143, adv: 0.585969, recon: 0.226912, id: 1.173203] time: 0:06:10.215931
# Inside 2nd for loop
# [Epoch 0/25] [Batch 133/995] [D loss: 0.540544, acc:  32%] [G loss: 6.666345, adv: 0.612682, recon: 0.187649, id: 0.759741] time: 0:06:12.707166
# Inside 2nd for loop
# [Epoch 0/25] [Batch 134/995] [D loss: 0.448895, acc:  27%] [G loss: 4.777869, adv: 0.499541, recon: 0.135100, id: 0.688411] time: 0:06:15.231249
# Inside 2nd for loop
# [Epoch 0/25] [Batch 135/995] [D loss: 0.234974, acc:  58%] [G loss: 5.976158, adv: 0.654735, recon: 0.178687, id: 0.658115] time: 0:06:17.754262
# Inside 2nd for loop
# [Epoch 0/25] [Batch 136/995] [D loss: 0.351883, acc:  34%] [G loss: 6.714323, adv: 0.663741, recon: 0.181693, id: 0.853104] time: 0:06:20.260241
# Inside 2nd for loop
# [Epoch 0/25] [Batch 137/995] [D loss: 0.337503, acc:  41%] [G loss: 7.393564, adv: 0.582472, recon: 0.235290, id: 0.553829] time: 0:06:22.770474
# Inside 2nd for loop
# [Epoch 0/25] [Batch 138/995] [D loss: 0.575871, acc:  22%] [G loss: 7.446373, adv: 0.643954, recon: 0.220776, id: 0.632696] time: 0:06:25.275113
# Inside 2nd for loop
# [Epoch 0/25] [Batch 139/995] [D loss: 0.471997, acc:  46%] [G loss: 6.198531, adv: 0.634631, recon: 0.193657, id: 0.431286] time: 0:06:27.857163
# Inside 2nd for loop
# [Epoch 0/25] [Batch 140/995] [D loss: 0.548987, acc:   2%] [G loss: 8.489445, adv: 0.418753, recon: 0.306004, id: 0.693684] time: 0:06:30.419110
# Inside 2nd for loop
# [Epoch 0/25] [Batch 141/995] [D loss: 0.359643, acc:  21%] [G loss: 7.157181, adv: 0.564195, recon: 0.247847, id: 0.463231] time: 0:06:32.952546
# Inside 2nd for loop
# [Epoch 0/25] [Batch 142/995] [D loss: 0.593687, acc:   3%] [G loss: 6.228478, adv: 0.492679, recon: 0.180055, id: 0.829306] time: 0:06:35.490269
# Inside 2nd for loop
# [Epoch 0/25] [Batch 143/995] [D loss: 0.374962, acc:  22%] [G loss: 5.281986, adv: 0.548836, recon: 0.154463, id: 0.473883] time: 0:06:38.040822
# Inside 2nd for loop
# [Epoch 0/25] [Batch 144/995] [D loss: 0.474189, acc:  16%] [G loss: 7.884489, adv: 0.496712, recon: 0.265525, id: 0.881402] time: 0:06:40.549532
# Inside 2nd for loop
# [Epoch 0/25] [Batch 145/995] [D loss: 0.424887, acc:  19%] [G loss: 6.746303, adv: 0.501441, recon: 0.217501, id: 0.617263] time: 0:06:43.051076
# Inside 2nd for loop
# [Epoch 0/25] [Batch 146/995] [D loss: 0.460323, acc:  17%] [G loss: 6.428618, adv: 0.542266, recon: 0.163921, id: 1.357687] time: 0:06:45.551762
# Inside 2nd for loop
# [Epoch 0/25] [Batch 147/995] [D loss: 0.186695, acc:  60%] [G loss: 6.381668, adv: 0.934388, recon: 0.141324, id: 0.590244] time: 0:06:48.078913
# Inside 2nd for loop
# [Epoch 0/25] [Batch 148/995] [D loss: 0.471932, acc:  31%] [G loss: 6.903850, adv: 0.467491, recon: 0.233914, id: 0.575941] time: 0:06:50.549329
# Inside 2nd for loop
# [Epoch 0/25] [Batch 149/995] [D loss: 0.372636, acc:  42%] [G loss: 6.419020, adv: 0.654419, recon: 0.192270, id: 0.530920] time: 0:06:53.090779
# Inside 2nd for loop
# [Epoch 0/25] [Batch 150/995] [D loss: 0.444248, acc:  18%] [G loss: 8.010235, adv: 0.537927, recon: 0.252990, id: 0.824531] time: 0:06:55.591501
# Inside 2nd for loop
# [Epoch 0/25] [Batch 151/995] [D loss: 0.496813, acc:  39%] [G loss: 7.455297, adv: 0.485408, recon: 0.278833, id: 0.434366] time: 0:06:58.138804
# Inside 2nd for loop
# [Epoch 0/25] [Batch 152/995] [D loss: 0.460541, acc:  14%] [G loss: 5.863626, adv: 0.485956, recon: 0.199123, id: 0.411426] time: 0:07:00.642872
# Inside 2nd for loop
# [Epoch 0/25] [Batch 153/995] [D loss: 0.435535, acc:  12%] [G loss: 7.300044, adv: 0.502537, recon: 0.222418, id: 0.849333] time: 0:07:03.174226
# Inside 2nd for loop
# [Epoch 0/25] [Batch 154/995] [D loss: 0.413207, acc:  16%] [G loss: 5.934569, adv: 0.502144, recon: 0.172186, id: 0.843492] time: 0:07:05.664604
# Inside 2nd for loop
# [Epoch 0/25] [Batch 155/995] [D loss: 0.424441, acc:   8%] [G loss: 6.325422, adv: 0.486145, recon: 0.226738, id: 0.484926] time: 0:07:08.173539
# Inside 2nd for loop
# [Epoch 0/25] [Batch 156/995] [D loss: 0.288293, acc:  50%] [G loss: 5.574026, adv: 0.614694, recon: 0.138127, id: 0.592278] time: 0:07:10.695793
# Inside 2nd for loop
# [Epoch 0/25] [Batch 157/995] [D loss: 0.190742, acc:  68%] [G loss: 6.517040, adv: 0.667777, recon: 0.164857, id: 0.689284] time: 0:07:13.186771
# Inside 2nd for loop
# [Epoch 0/25] [Batch 158/995] [D loss: 0.107092, acc:  90%] [G loss: 7.706420, adv: 0.827254, recon: 0.219363, id: 0.549559] time: 0:07:15.691379
# Inside 2nd for loop
# [Epoch 0/25] [Batch 159/995] [D loss: 0.191208, acc:  75%] [G loss: 5.716997, adv: 0.619730, recon: 0.133527, id: 0.724334] time: 0:07:18.194637
# Inside 2nd for loop
# [Epoch 0/25] [Batch 160/995] [D loss: 0.058390, acc:  99%] [G loss: 6.142482, adv: 0.862732, recon: 0.143585, id: 0.518256] time: 0:07:20.732384
# Inside 2nd for loop
# [Epoch 0/25] [Batch 161/995] [D loss: 0.299335, acc:  48%] [G loss: 6.797357, adv: 0.613319, recon: 0.210274, id: 0.584520] time: 0:07:23.258311
# Inside 2nd for loop
# [Epoch 0/25] [Batch 162/995] [D loss: 0.533764, acc:   2%] [G loss: 7.543313, adv: 0.500574, recon: 0.262504, id: 0.539386] time: 0:07:25.788182
# Inside 2nd for loop
# [Epoch 0/25] [Batch 163/995] [D loss: 0.177511, acc:  70%] [G loss: 5.991676, adv: 0.794221, recon: 0.152481, id: 0.466243] time: 0:07:28.372578
# Inside 2nd for loop
# [Epoch 0/25] [Batch 164/995] [D loss: 0.729946, acc:  10%] [G loss: 7.848132, adv: 0.600886, recon: 0.232731, id: 1.185948] time: 0:07:30.907631
# Inside 2nd for loop
# [Epoch 0/25] [Batch 165/995] [D loss: 0.203044, acc:  78%] [G loss: 7.708996, adv: 0.751392, recon: 0.219202, id: 0.809443] time: 0:07:33.427137
# Inside 2nd for loop
# [Epoch 0/25] [Batch 166/995] [D loss: 0.473133, acc:  21%] [G loss: 7.949916, adv: 0.426116, recon: 0.295534, id: 0.452712] time: 0:07:35.964923
# Inside 2nd for loop
# [Epoch 0/25] [Batch 167/995] [D loss: 0.369717, acc:  16%] [G loss: 6.201652, adv: 0.557199, recon: 0.201123, id: 0.387114] time: 0:07:38.481624
# Inside 2nd for loop
# [Epoch 0/25] [Batch 168/995] [D loss: 0.365610, acc:  27%] [G loss: 7.633245, adv: 0.568800, recon: 0.266906, id: 0.512268] time: 0:07:41.035436
# Inside 2nd for loop
# [Epoch 0/25] [Batch 169/995] [D loss: 0.459256, acc:   8%] [G loss: 6.473142, adv: 0.511181, recon: 0.187195, id: 0.679228] time: 0:07:43.572851
# Inside 2nd for loop
# [Epoch 0/25] [Batch 170/995] [D loss: 0.545519, acc:   4%] [G loss: 7.247796, adv: 0.430692, recon: 0.262680, id: 0.641523] time: 0:07:46.108245
# Inside 2nd for loop
# [Epoch 0/25] [Batch 171/995] [D loss: 0.478710, acc:   8%] [G loss: 6.617901, adv: 0.481519, recon: 0.200539, id: 0.660257] time: 0:07:48.658317
# Inside 2nd for loop
# [Epoch 0/25] [Batch 172/995] [D loss: 0.550961, acc:   5%] [G loss: 6.372333, adv: 0.499735, recon: 0.176313, id: 1.088381] time: 0:07:51.193203
# Inside 2nd for loop
# [Epoch 0/25] [Batch 173/995] [D loss: 0.433974, acc:  14%] [G loss: 6.410834, adv: 0.492714, recon: 0.199118, id: 0.709390] time: 0:07:53.714808
# Inside 2nd for loop
# [Epoch 0/25] [Batch 174/995] [D loss: 0.430157, acc:   8%] [G loss: 6.567137, adv: 0.444419, recon: 0.218928, id: 0.549935] time: 0:07:56.255192
# Inside 2nd for loop
# [Epoch 0/25] [Batch 175/995] [D loss: 0.443072, acc:  17%] [G loss: 7.474463, adv: 0.469670, recon: 0.262555, id: 0.575019] time: 0:07:58.787973
# Inside 2nd for loop
# [Epoch 0/25] [Batch 176/995] [D loss: 0.365586, acc:  29%] [G loss: 5.955499, adv: 0.532970, recon: 0.180813, id: 0.641162] time: 0:08:01.340887
# Inside 2nd for loop
# [Epoch 0/25] [Batch 177/995] [D loss: 0.285128, acc:  41%] [G loss: 5.777044, adv: 0.559190, recon: 0.169843, id: 0.528379] time: 0:08:03.832678
# Inside 2nd for loop
# [Epoch 0/25] [Batch 178/995] [D loss: 0.314316, acc:  30%] [G loss: 5.829133, adv: 0.534582, recon: 0.190936, id: 0.394863] time: 0:08:06.349867
# Inside 2nd for loop
# [Epoch 0/25] [Batch 179/995] [D loss: 0.409162, acc:  11%] [G loss: 6.775132, adv: 0.475447, recon: 0.225501, id: 0.575161] time: 0:08:08.851435
# Inside 2nd for loop
# [Epoch 0/25] [Batch 180/995] [D loss: 0.272518, acc:  49%] [G loss: 6.400677, adv: 0.611265, recon: 0.181428, id: 0.762045] time: 0:08:11.359044
# Inside 2nd for loop
# [Epoch 0/25] [Batch 181/995] [D loss: 0.148448, acc:  77%] [G loss: 7.852896, adv: 0.950904, recon: 0.211377, id: 0.906153] time: 0:08:13.871874
# Inside 2nd for loop
# [Epoch 0/25] [Batch 182/995] [D loss: 0.251757, acc:  66%] [G loss: 12.335891, adv: 0.568963, recon: 0.460868, id: 0.966576] time: 0:08:16.375864
# Inside 2nd for loop
# [Epoch 0/25] [Batch 183/995] [D loss: 0.364758, acc:  16%] [G loss: 5.259508, adv: 0.512252, recon: 0.169232, id: 0.285788] time: 0:08:18.908629
# Inside 2nd for loop
# [Epoch 0/25] [Batch 184/995] [D loss: 0.491242, acc:  30%] [G loss: 5.802043, adv: 0.418499, recon: 0.193056, id: 0.418520] time: 0:08:21.428104
# Inside 2nd for loop
# [Epoch 0/25] [Batch 185/995] [D loss: 0.356545, acc:  39%] [G loss: 6.874617, adv: 0.676002, recon: 0.199689, id: 0.899935] time: 0:08:23.963899
# Inside 2nd for loop
# [Epoch 0/25] [Batch 186/995] [D loss: 0.215571, acc:  62%] [G loss: 7.978948, adv: 0.805960, recon: 0.249909, id: 0.578316] time: 0:08:26.484034
# Inside 2nd for loop
# [Epoch 0/25] [Batch 187/995] [D loss: 0.374972, acc:  35%] [G loss: 6.982871, adv: 0.478955, recon: 0.196488, id: 1.220452] time: 0:08:29.022170
# Inside 2nd for loop
# [Epoch 0/25] [Batch 188/995] [D loss: 0.216090, acc:  63%] [G loss: 6.134974, adv: 0.739600, recon: 0.166411, id: 0.523080] time: 0:08:31.525762
# Inside 2nd for loop
# [Epoch 0/25] [Batch 189/995] [D loss: 0.594228, acc:  29%] [G loss: 6.729982, adv: 0.413388, recon: 0.241760, id: 0.571050] time: 0:08:34.068666
# Inside 2nd for loop
# [Epoch 0/25] [Batch 190/995] [D loss: 0.315939, acc:  32%] [G loss: 6.158206, adv: 0.638347, recon: 0.175420, id: 0.554627] time: 0:08:36.585777
# Inside 2nd for loop
# [Epoch 0/25] [Batch 191/995] [D loss: 0.449102, acc:  25%] [G loss: 7.451485, adv: 0.449951, recon: 0.267549, id: 0.550594] time: 0:08:39.085382
# Inside 2nd for loop
# [Epoch 0/25] [Batch 192/995] [D loss: 0.581459, acc:   3%] [G loss: 6.342563, adv: 0.369022, recon: 0.234806, id: 0.449681] time: 0:08:41.579646
# Inside 2nd for loop
# [Epoch 0/25] [Batch 193/995] [D loss: 0.295769, acc:  37%] [G loss: 7.104949, adv: 0.574551, recon: 0.245880, id: 0.426128] time: 0:08:44.138631
# Inside 2nd for loop
# [Epoch 0/25] [Batch 194/995] [D loss: 0.200042, acc:  72%] [G loss: 6.198276, adv: 0.723342, recon: 0.190211, id: 0.438370] time: 0:08:46.720331
# Inside 2nd for loop
# [Epoch 0/25] [Batch 195/995] [D loss: 0.545687, acc:  24%] [G loss: 6.373806, adv: 0.372671, recon: 0.226192, id: 0.503377] time: 0:08:49.281333
# Inside 2nd for loop
# [Epoch 0/25] [Batch 196/995] [D loss: 0.450380, acc:  21%] [G loss: 4.583783, adv: 0.484169, recon: 0.147480, id: 0.248678] time: 0:08:51.826357
# Inside 2nd for loop
# [Epoch 0/25] [Batch 197/995] [D loss: 0.429444, acc:  11%] [G loss: 6.770029, adv: 0.508084, recon: 0.229545, id: 0.512846] time: 0:08:54.372083
# Inside 2nd for loop
# [Epoch 0/25] [Batch 198/995] [D loss: 0.565200, acc:  18%] [G loss: 4.865382, adv: 0.474504, recon: 0.159175, id: 0.229801] time: 0:08:56.879536
# Inside 2nd for loop
# [Epoch 0/25] [Batch 199/995] [D loss: 0.386491, acc:  29%] [G loss: 5.077587, adv: 0.500063, recon: 0.157754, id: 0.290247] time: 0:08:59.397314
# Inside 2nd for loop
# [Epoch 0/25] [Batch 200/995] [D loss: 0.334264, acc:  31%] [G loss: 5.391142, adv: 0.481151, recon: 0.167328, id: 0.519834] time: 0:09:01.926739
# Inside 2nd for loop
# [Epoch 0/25] [Batch 201/995] [D loss: 0.315727, acc:  37%] [G loss: 6.504682, adv: 0.551056, recon: 0.221332, id: 0.417480] time: 0:09:05.849100
# Inside 2nd for loop
# [Epoch 0/25] [Batch 202/995] [D loss: 0.471389, acc:   2%] [G loss: 5.932258, adv: 0.437432, recon: 0.204637, id: 0.375750] time: 0:09:08.406538
# Inside 2nd for loop
# [Epoch 0/25] [Batch 203/995] [D loss: 0.442792, acc:  16%] [G loss: 6.892178, adv: 0.458539, recon: 0.235089, id: 0.553170] time: 0:09:11.045785
# Inside 2nd for loop
# [Epoch 0/25] [Batch 204/995] [D loss: 0.331111, acc:  24%] [G loss: 6.372952, adv: 0.511794, recon: 0.222377, id: 0.431827] time: 0:09:13.556606
# Inside 2nd for loop
# [Epoch 0/25] [Batch 205/995] [D loss: 0.358630, acc:  29%] [G loss: 6.659973, adv: 0.489200, recon: 0.229622, id: 0.311587] time: 0:09:16.054552
# Inside 2nd for loop
# [Epoch 0/25] [Batch 206/995] [D loss: 0.356860, acc:  37%] [G loss: 4.538560, adv: 0.570460, recon: 0.135406, id: 0.374170] time: 0:09:18.548626
# Inside 2nd for loop
# [Epoch 0/25] [Batch 207/995] [D loss: 0.342231, acc:  26%] [G loss: 5.366162, adv: 0.511188, recon: 0.153586, id: 0.419954] time: 0:09:21.061143
# Inside 2nd for loop
# [Epoch 0/25] [Batch 208/995] [D loss: 0.374341, acc:  18%] [G loss: 5.777999, adv: 0.468818, recon: 0.206509, id: 0.423468] time: 0:09:23.564480
# Inside 2nd for loop
# [Epoch 0/25] [Batch 209/995] [D loss: 0.453025, acc:  21%] [G loss: 8.417696, adv: 0.490160, recon: 0.318187, id: 0.461240] time: 0:09:26.070443
# Inside 2nd for loop
# [Epoch 0/25] [Batch 210/995] [D loss: 0.232231, acc:  55%] [G loss: 6.981162, adv: 0.626775, recon: 0.221768, id: 0.449894] time: 0:09:28.608103
# Inside 2nd for loop
# [Epoch 0/25] [Batch 211/995] [D loss: 0.528395, acc:  33%] [G loss: 8.447870, adv: 0.565495, recon: 0.308027, id: 0.364378] time: 0:09:31.149009
# Inside 2nd for loop
# [Epoch 0/25] [Batch 212/995] [D loss: 0.346507, acc:  32%] [G loss: 6.614568, adv: 0.550667, recon: 0.228612, id: 0.517253] time: 0:09:33.641950
# Inside 2nd for loop
# [Epoch 0/25] [Batch 213/995] [D loss: 0.417930, acc:  15%] [G loss: 8.626825, adv: 0.458087, recon: 0.321583, id: 0.570137] time: 0:09:36.178694
# Inside 2nd for loop
# [Epoch 0/25] [Batch 214/995] [D loss: 0.406149, acc:  19%] [G loss: 6.292469, adv: 0.479054, recon: 0.228475, id: 0.436254] time: 0:09:38.698602
# Inside 2nd for loop
# [Epoch 0/25] [Batch 215/995] [D loss: 0.482941, acc:  19%] [G loss: 6.647476, adv: 0.483647, recon: 0.202972, id: 0.797137] time: 0:09:41.204528
# Inside 2nd for loop
# [Epoch 0/25] [Batch 216/995] [D loss: 0.278944, acc:  58%] [G loss: 6.147880, adv: 0.698538, recon: 0.205877, id: 0.245757] time: 0:09:43.738611
# Inside 2nd for loop
# [Epoch 0/25] [Batch 217/995] [D loss: 0.243118, acc:  66%] [G loss: 6.959096, adv: 0.692059, recon: 0.231956, id: 0.462485] time: 0:09:46.285210
# Inside 2nd for loop
# [Epoch 0/25] [Batch 218/995] [D loss: 0.479456, acc:   5%] [G loss: 4.956975, adv: 0.397203, recon: 0.162210, id: 0.478513] time: 0:09:48.804451
# Inside 2nd for loop
# [Epoch 0/25] [Batch 219/995] [D loss: 0.211276, acc:  64%] [G loss: 7.099820, adv: 0.683713, recon: 0.244595, id: 0.364672] time: 0:09:51.322386
# Inside 2nd for loop
# [Epoch 0/25] [Batch 220/995] [D loss: 0.419757, acc:  25%] [G loss: 5.400544, adv: 0.443607, recon: 0.187306, id: 0.208746] time: 0:09:53.844557
# Inside 2nd for loop
# [Epoch 0/25] [Batch 221/995] [D loss: 0.363783, acc:  23%] [G loss: 6.919600, adv: 0.512942, recon: 0.248596, id: 0.410506] time: 0:09:56.393577
# Inside 2nd for loop
# [Epoch 0/25] [Batch 222/995] [D loss: 0.587332, acc:   7%] [G loss: 7.638176, adv: 0.437382, recon: 0.251556, id: 1.052191] time: 0:09:58.899288
# Inside 2nd for loop
# [Epoch 0/25] [Batch 223/995] [D loss: 0.302267, acc:  47%] [G loss: 6.915390, adv: 0.534848, recon: 0.234246, id: 0.602279] time: 0:10:01.390976
# Inside 2nd for loop
# [Epoch 0/25] [Batch 224/995] [D loss: 0.333521, acc:  41%] [G loss: 6.080788, adv: 0.536319, recon: 0.203936, id: 0.351416] time: 0:10:03.906505
# Inside 2nd for loop
# [Epoch 0/25] [Batch 225/995] [D loss: 0.360159, acc:  20%] [G loss: 5.050611, adv: 0.489774, recon: 0.155996, id: 0.599294] time: 0:10:06.431654
# Inside 2nd for loop
# [Epoch 0/25] [Batch 226/995] [D loss: 0.349194, acc:  24%] [G loss: 7.050235, adv: 0.492386, recon: 0.254135, id: 0.398763] time: 0:10:08.945990
# Inside 2nd for loop
# [Epoch 0/25] [Batch 227/995] [D loss: 0.350609, acc:  13%] [G loss: 6.220195, adv: 0.475197, recon: 0.208049, id: 0.512902] time: 0:10:11.465858
# Inside 2nd for loop
# [Epoch 0/25] [Batch 228/995] [D loss: 0.404713, acc:  17%] [G loss: 6.591322, adv: 0.460947, recon: 0.228318, id: 0.799156] time: 0:10:14.003828
# Inside 2nd for loop
# [Epoch 0/25] [Batch 229/995] [D loss: 0.355394, acc:  22%] [G loss: 5.073240, adv: 0.456604, recon: 0.171621, id: 0.233434] time: 0:10:16.538538
# Inside 2nd for loop
# [Epoch 0/25] [Batch 230/995] [D loss: 0.251670, acc:  62%] [G loss: 6.667185, adv: 1.003327, recon: 0.189395, id: 0.239889] time: 0:10:19.065029
# Inside 2nd for loop
# [Epoch 0/25] [Batch 231/995] [D loss: 0.272707, acc:  51%] [G loss: 7.034326, adv: 0.568493, recon: 0.239784, id: 0.408379] time: 0:10:21.632787
# Inside 2nd for loop
# [Epoch 0/25] [Batch 232/995] [D loss: 0.329326, acc:  33%] [G loss: 6.845515, adv: 0.544817, recon: 0.239741, id: 0.398619] time: 0:10:24.193856
# Inside 2nd for loop
# [Epoch 0/25] [Batch 233/995] [D loss: 0.216748, acc:  64%] [G loss: 6.601508, adv: 0.717085, recon: 0.213540, id: 0.287025] time: 0:10:26.764309
# Inside 2nd for loop
# [Epoch 0/25] [Batch 234/995] [D loss: 0.690949, acc:  10%] [G loss: 5.619219, adv: 0.490584, recon: 0.191701, id: 0.455971] time: 0:10:29.383940
# Inside 2nd for loop
# [Epoch 0/25] [Batch 235/995] [D loss: 0.265040, acc:  54%] [G loss: 6.378686, adv: 0.654688, recon: 0.193637, id: 0.366803] time: 0:10:31.913330
# Inside 2nd for loop
# [Epoch 0/25] [Batch 236/995] [D loss: 0.455489, acc:   5%] [G loss: 4.259428, adv: 0.373111, recon: 0.124747, id: 0.621140] time: 0:10:34.403660
# Inside 2nd for loop
# [Epoch 0/25] [Batch 237/995] [D loss: 2.399771, acc:   7%] [G loss: 13.957160, adv: 0.663668, recon: 0.552912, id: 0.952823] time: 0:10:36.928584
# Inside 2nd for loop
# [Epoch 0/25] [Batch 238/995] [D loss: 0.286914, acc:  52%] [G loss: 7.338300, adv: 0.669286, recon: 0.225405, id: 0.655589] time: 0:10:39.465685
# Inside 2nd for loop
# [Epoch 0/25] [Batch 239/995] [D loss: 0.351917, acc:  33%] [G loss: 5.443743, adv: 0.555989, recon: 0.134425, id: 0.816930] time: 0:10:42.014647
# Inside 2nd for loop
# [Epoch 0/25] [Batch 240/995] [D loss: 0.405203, acc:  33%] [G loss: 6.183147, adv: 0.487053, recon: 0.217755, id: 0.473340] time: 0:10:44.552966
# Inside 2nd for loop
# [Epoch 0/25] [Batch 241/995] [D loss: 0.381246, acc:  36%] [G loss: 6.099628, adv: 0.471388, recon: 0.195831, id: 0.467812] time: 0:10:47.073979
# Inside 2nd for loop
# [Epoch 0/25] [Batch 242/995] [D loss: 0.309914, acc:  34%] [G loss: 5.138537, adv: 0.599098, recon: 0.152106, id: 0.309057] time: 0:10:49.605347
# Inside 2nd for loop
# [Epoch 0/25] [Batch 243/995] [D loss: 0.370505, acc:  36%] [G loss: 7.086924, adv: 0.455105, recon: 0.259432, id: 0.430453] time: 0:10:52.150453
# Inside 2nd for loop
# [Epoch 0/25] [Batch 244/995] [D loss: 0.409786, acc:  26%] [G loss: 6.851120, adv: 0.462686, recon: 0.241942, id: 0.429386] time: 0:10:54.657732
# Inside 2nd for loop
# [Epoch 0/25] [Batch 245/995] [D loss: 0.461361, acc:  19%] [G loss: 5.258575, adv: 0.412511, recon: 0.171943, id: 0.553695] time: 0:10:57.173812
# Inside 2nd for loop
# [Epoch 0/25] [Batch 246/995] [D loss: 0.342002, acc:  28%] [G loss: 6.496783, adv: 0.519511, recon: 0.231783, id: 0.360325] time: 0:10:59.714765
# Inside 2nd for loop
# [Epoch 0/25] [Batch 247/995] [D loss: 0.391129, acc:  16%] [G loss: 4.735583, adv: 0.403579, recon: 0.146874, id: 0.497894] time: 0:11:02.237405
# Inside 2nd for loop
# [Epoch 0/25] [Batch 248/995] [D loss: 0.330304, acc:  31%] [G loss: 5.532600, adv: 0.490196, recon: 0.178049, id: 0.390190] time: 0:11:04.749565
# Inside 2nd for loop
# [Epoch 0/25] [Batch 249/995] [D loss: 0.269613, acc:  46%] [G loss: 4.584012, adv: 0.564017, recon: 0.135391, id: 0.229206] time: 0:11:07.261491
# Inside 2nd for loop
# [Epoch 0/25] [Batch 250/995] [D loss: 0.486315, acc:  15%] [G loss: 7.997846, adv: 0.407457, recon: 0.309265, id: 0.415295] time: 0:11:09.790842
# Inside 2nd for loop
# [Epoch 0/25] [Batch 251/995] [D loss: 0.280926, acc:  44%] [G loss: 5.739348, adv: 0.576945, recon: 0.166403, id: 0.521509] time: 0:11:12.305110
# Inside 2nd for loop
# [Epoch 0/25] [Batch 252/995] [D loss: 0.665361, acc:   3%] [G loss: 5.733433, adv: 0.298367, recon: 0.197424, id: 0.546962] time: 0:11:14.829696
# Inside 2nd for loop
# [Epoch 0/25] [Batch 253/995] [D loss: 0.262226, acc:  48%] [G loss: 7.122077, adv: 0.539244, recon: 0.235961, id: 0.455106] time: 0:11:17.332511
# Inside 2nd for loop
# [Epoch 0/25] [Batch 254/995] [D loss: 0.295571, acc:  43%] [G loss: 6.319142, adv: 0.488806, recon: 0.201639, id: 0.493053] time: 0:11:19.873349
# Inside 2nd for loop
# [Epoch 0/25] [Batch 255/995] [D loss: 0.381353, acc:  13%] [G loss: 6.138818, adv: 0.433881, recon: 0.195887, id: 0.971724] time: 0:11:22.390144
# Inside 2nd for loop
# [Epoch 0/25] [Batch 256/995] [D loss: 0.265556, acc:  39%] [G loss: 4.614718, adv: 0.529425, recon: 0.139188, id: 0.244131] time: 0:11:24.924337
# Inside 2nd for loop
# [Epoch 0/25] [Batch 257/995] [D loss: 0.376797, acc:  28%] [G loss: 5.708162, adv: 0.403939, recon: 0.193036, id: 0.500958] time: 0:11:27.428612
# Inside 2nd for loop
# [Epoch 0/25] [Batch 258/995] [D loss: 0.246327, acc:  47%] [G loss: 4.395541, adv: 0.554880, recon: 0.120484, id: 0.167638] time: 0:11:30.004885
# Inside 2nd for loop
# [Epoch 0/25] [Batch 259/995] [D loss: 0.293752, acc:  42%] [G loss: 5.513602, adv: 0.453752, recon: 0.177866, id: 0.422140] time: 0:11:32.495296
# Inside 2nd for loop
# [Epoch 0/25] [Batch 260/995] [D loss: 0.271805, acc:  43%] [G loss: 6.318455, adv: 0.511174, recon: 0.211073, id: 0.571266] time: 0:11:34.993374
# Inside 2nd for loop
# [Epoch 0/25] [Batch 261/995] [D loss: 0.380100, acc:  16%] [G loss: 5.373518, adv: 0.431280, recon: 0.175816, id: 0.385848] time: 0:11:37.516003
# Inside 2nd for loop
# [Epoch 0/25] [Batch 262/995] [D loss: 0.261326, acc:  51%] [G loss: 5.730707, adv: 0.547010, recon: 0.168361, id: 0.448321] time: 0:11:40.038594
# Inside 2nd for loop
# [Epoch 0/25] [Batch 263/995] [D loss: 0.404012, acc:  21%] [G loss: 4.794700, adv: 0.411026, recon: 0.161239, id: 0.414822] time: 0:11:42.571703
# Inside 2nd for loop
# [Epoch 0/25] [Batch 264/995] [D loss: 0.381595, acc:  24%] [G loss: 4.771636, adv: 0.431574, recon: 0.144335, id: 0.363438] time: 0:11:45.064623
# Inside 2nd for loop
# [Epoch 0/25] [Batch 265/995] [D loss: 0.276533, acc:  45%] [G loss: 5.050275, adv: 0.529629, recon: 0.161772, id: 0.194890] time: 0:11:47.567092
# Inside 2nd for loop
# [Epoch 0/25] [Batch 266/995] [D loss: 0.261120, acc:  45%] [G loss: 6.571494, adv: 0.506045, recon: 0.206184, id: 0.573610] time: 0:11:50.106202
# Inside 2nd for loop
# [Epoch 0/25] [Batch 267/995] [D loss: 0.513773, acc:  28%] [G loss: 5.382369, adv: 0.428959, recon: 0.189525, id: 0.364039] time: 0:11:52.635247
# Inside 2nd for loop
# [Epoch 0/25] [Batch 268/995] [D loss: 0.287973, acc:  48%] [G loss: 4.768513, adv: 0.499958, recon: 0.151357, id: 0.121662] time: 0:11:55.135928
# Inside 2nd for loop
# ...
# Inside 2nd for loop
# [Epoch 6/25] [Batch 521/995] [D loss: 0.134393, acc:  91%] [G loss: 4.678673, adv: 0.466597, recon: 0.162358, id: 0.245703] time: 4:35:01.297210
# Inside 2nd for loop
# [Epoch 6/25] [Batch 522/995] [D loss: 0.131847, acc:  81%] [G loss: 2.750504, adv: 0.563108, recon: 0.064484, id: 0.231170] time: 4:35:03.763703
# Inside 2nd for loop
# [Epoch 6/25] [Batch 523/995] [D loss: 0.132831, acc:  83%] [G loss: 3.418545, adv: 0.608284, recon: 0.084734, id: 0.276659] time: 4:35:06.246754
# Inside 2nd for loop
# [Epoch 6/25] [Batch 524/995] [D loss: 0.634268, acc:  11%] [G loss: 2.735655, adv: 0.308712, recon: 0.089798, id: 0.076419] time: 4:35:08.681377
# Inside 2nd for loop
# [Epoch 6/25] [Batch 525/995] [D loss: 0.294453, acc:  42%] [G loss: 2.625918, adv: 0.460566, recon: 0.060431, id: 0.080978] time: 4:35:11.146774
# Inside 2nd for loop
# [Epoch 6/25] [Batch 526/995] [D loss: 0.231172, acc:  62%] [G loss: 2.919219, adv: 0.518932, recon: 0.080655, id: 0.102695] time: 4:35:13.613373
# Inside 2nd for loop
# [Epoch 6/25] [Batch 527/995] [D loss: 0.187688, acc:  70%] [G loss: 2.755373, adv: 0.585303, recon: 0.066866, id: 0.139176] time: 4:35:16.084265
# Inside 2nd for loop
# [Epoch 6/25] [Batch 528/995] [D loss: 0.138244, acc:  90%] [G loss: 2.991959, adv: 0.579505, recon: 0.060799, id: 0.173550] time: 4:35:18.553093
# Inside 2nd for loop
# [Epoch 6/25] [Batch 529/995] [D loss: 0.254669, acc:  54%] [G loss: 3.106589, adv: 0.342155, recon: 0.099587, id: 0.262405] time: 4:35:21.005298
# Inside 2nd for loop
# [Epoch 6/25] [Batch 530/995] [D loss: 0.123030, acc:  83%] [G loss: 4.659125, adv: 0.515679, recon: 0.146621, id: 0.331902] time: 4:35:23.489094
# Inside 2nd for loop
# [Epoch 6/25] [Batch 531/995] [D loss: 0.409759, acc:  22%] [G loss: 2.521503, adv: 0.298553, recon: 0.070901, id: 0.249827] time: 4:35:25.979310
# Inside 2nd for loop
# [Epoch 6/25] [Batch 532/995] [D loss: 0.320359, acc:  40%] [G loss: 3.095631, adv: 0.350885, recon: 0.101887, id: 0.182512] time: 4:35:28.455006
# Inside 2nd for loop
# [Epoch 6/25] [Batch 533/995] [D loss: 0.263290, acc:  55%] [G loss: 3.407148, adv: 0.392305, recon: 0.101194, id: 0.399718] time: 4:35:30.932978
# Inside 2nd for loop
# [Epoch 6/25] [Batch 534/995] [D loss: 0.204101, acc:  66%] [G loss: 3.946877, adv: 0.469997, recon: 0.121329, id: 0.230573] time: 4:35:33.415815
# Inside 2nd for loop
# [Epoch 6/25] [Batch 535/995] [D loss: 0.195429, acc:  75%] [G loss: 3.896692, adv: 0.587826, recon: 0.102411, id: 0.342444] time: 4:35:35.908938
# Inside 2nd for loop
# [Epoch 6/25] [Batch 536/995] [D loss: 0.217890, acc:  62%] [G loss: 3.580135, adv: 0.391257, recon: 0.098195, id: 0.315055] time: 4:35:38.418347
# Inside 2nd for loop
# [Epoch 6/25] [Batch 537/995] [D loss: 0.273421, acc:  40%] [G loss: 3.378338, adv: 0.363617, recon: 0.110918, id: 0.178157] time: 4:35:40.937237
# Inside 2nd for loop
# [Epoch 6/25] [Batch 538/995] [D loss: 0.206543, acc:  58%] [G loss: 3.575548, adv: 0.637917, recon: 0.094963, id: 0.252838] time: 4:35:43.456716
# Inside 2nd for loop
# [Epoch 6/25] [Batch 539/995] [D loss: 0.217263, acc:  68%] [G loss: 3.428026, adv: 0.419657, recon: 0.106315, id: 0.369981] time: 4:35:45.958284
# Inside 2nd for loop
# [Epoch 6/25] [Batch 540/995] [D loss: 0.120379, acc:  98%] [G loss: 3.192841, adv: 0.504963, recon: 0.086990, id: 0.151143] time: 4:35:48.454582
# Inside 2nd for loop
# [Epoch 6/25] [Batch 541/995] [D loss: 0.221832, acc:  63%] [G loss: 2.856972, adv: 0.397148, recon: 0.086102, id: 0.123416] time: 4:35:50.934091
# Inside 2nd for loop
# [Epoch 6/25] [Batch 542/995] [D loss: 0.223533, acc:  72%] [G loss: 3.037305, adv: 0.438960, recon: 0.091559, id: 0.063072] time: 4:35:53.439716
# Inside 2nd for loop
# [Epoch 6/25] [Batch 543/995] [D loss: 0.133329, acc:  89%] [G loss: 3.201008, adv: 0.552827, recon: 0.085688, id: 0.084000] time: 4:35:55.961528
# Inside 2nd for loop
# [Epoch 6/25] [Batch 544/995] [D loss: 0.097073, acc:  96%] [G loss: 3.193902, adv: 0.592443, recon: 0.079735, id: 0.088513] time: 4:35:58.438569
# Inside 2nd for loop
# [Epoch 6/25] [Batch 545/995] [D loss: 0.178298, acc:  71%] [G loss: 3.360510, adv: 0.582381, recon: 0.087754, id: 0.235321] time: 4:36:00.908858
# Inside 2nd for loop
# [Epoch 6/25] [Batch 546/995] [D loss: 0.234713, acc:  59%] [G loss: 3.614579, adv: 0.595203, recon: 0.093058, id: 0.274678] time: 4:36:03.362444
# Inside 2nd for loop
# [Epoch 6/25] [Batch 547/995] [D loss: 0.081000, acc:  96%] [G loss: 3.372156, adv: 0.667532, recon: 0.081028, id: 0.245844] time: 4:36:05.826363
# Inside 2nd for loop
# [Epoch 6/25] [Batch 548/995] [D loss: 0.286575, acc:  50%] [G loss: 1.992168, adv: 0.450602, recon: 0.043648, id: 0.089088] time: 4:36:08.335427
# Inside 2nd for loop
# [Epoch 6/25] [Batch 549/995] [D loss: 0.162817, acc:  75%] [G loss: 3.382925, adv: 0.703215, recon: 0.058929, id: 0.531450] time: 4:36:10.834042
# Inside 2nd for loop
# [Epoch 6/25] [Batch 550/995] [D loss: 0.328899, acc:  49%] [G loss: 3.900377, adv: 0.481076, recon: 0.112253, id: 0.284836] time: 4:36:13.408896
# Inside 2nd for loop
# [Epoch 6/25] [Batch 551/995] [D loss: 0.240392, acc:  60%] [G loss: 3.528435, adv: 0.356099, recon: 0.119012, id: 0.208985] time: 4:36:15.955349
# Inside 2nd for loop
# [Epoch 6/25] [Batch 552/995] [D loss: 0.231133, acc:  66%] [G loss: 4.769037, adv: 0.574069, recon: 0.147925, id: 0.429074] time: 4:36:18.460061
# Inside 2nd for loop
# [Epoch 6/25] [Batch 553/995] [D loss: 0.094250, acc:  89%] [G loss: 3.957076, adv: 0.799008, recon: 0.100188, id: 0.199793] time: 4:36:20.947179
# Inside 2nd for loop
# [Epoch 6/25] [Batch 554/995] [D loss: 0.127842, acc:  89%] [G loss: 4.365655, adv: 0.606094, recon: 0.135285, id: 0.204521] time: 4:36:23.399646
# Inside 2nd for loop
# [Epoch 6/25] [Batch 555/995] [D loss: 0.440297, acc:   9%] [G loss: 3.440656, adv: 0.363377, recon: 0.111635, id: 0.211621] time: 4:36:25.871289
# Inside 2nd for loop
# [Epoch 6/25] [Batch 556/995] [D loss: 0.086076, acc:  97%] [G loss: 3.172538, adv: 0.619763, recon: 0.069350, id: 0.165115] time: 4:36:28.383296
# Inside 2nd for loop
# [Epoch 6/25] [Batch 557/995] [D loss: 0.177273, acc:  72%] [G loss: 3.156309, adv: 0.496552, recon: 0.083576, id: 0.186626] time: 4:36:30.858137
# Inside 2nd for loop
# [Epoch 6/25] [Batch 558/995] [D loss: 0.226640, acc:  62%] [G loss: 3.531404, adv: 0.603728, recon: 0.101015, id: 0.109916] time: 4:36:33.357928
# Inside 2nd for loop
# [Epoch 6/25] [Batch 559/995] [D loss: 0.248809, acc:  51%] [G loss: 4.667983, adv: 0.405995, recon: 0.161511, id: 0.426784] time: 4:36:36.003297
# Inside 2nd for loop
# [Epoch 6/25] [Batch 560/995] [D loss: 0.107283, acc:  92%] [G loss: 3.063100, adv: 0.595395, recon: 0.072091, id: 0.079496] time: 4:36:38.647488
# Inside 2nd for loop
# [Epoch 6/25] [Batch 561/995] [D loss: 0.334889, acc:  46%] [G loss: 2.905309, adv: 0.322308, recon: 0.088695, id: 0.184549] time: 4:36:41.293288
# Inside 2nd for loop
# [Epoch 6/25] [Batch 562/995] [D loss: 0.187901, acc:  74%] [G loss: 2.739335, adv: 0.496159, recon: 0.072075, id: 0.107501] time: 4:36:43.940294
# Inside 2nd for loop
# [Epoch 6/25] [Batch 563/995] [D loss: 0.053502, acc: 100%] [G loss: 4.098704, adv: 0.748728, recon: 0.105204, id: 0.336751] time: 4:36:46.574784
# Inside 2nd for loop
# [Epoch 6/25] [Batch 564/995] [D loss: 0.132081, acc:  90%] [G loss: 4.716682, adv: 0.521332, recon: 0.142579, id: 0.354069] time: 4:36:49.174560
# Inside 2nd for loop
# [Epoch 6/25] [Batch 565/995] [D loss: 0.062370, acc:  97%] [G loss: 3.899472, adv: 0.927931, recon: 0.085624, id: 0.150050] time: 4:36:51.798251
# Inside 2nd for loop
# [Epoch 6/25] [Batch 566/995] [D loss: 0.339572, acc:  33%] [G loss: 3.199885, adv: 0.316930, recon: 0.098925, id: 0.411797] time: 4:36:54.432581
# Inside 2nd for loop
# [Epoch 6/25] [Batch 567/995] [D loss: 0.460795, acc:  49%] [G loss: 3.002157, adv: 0.357582, recon: 0.090379, id: 0.345600] time: 4:36:57.083193
# Inside 2nd for loop
# [Epoch 6/25] [Batch 568/995] [D loss: 0.165367, acc:  82%] [G loss: 3.862617, adv: 0.560242, recon: 0.112719, id: 0.349759] time: 4:36:59.724154
# Inside 2nd for loop
# [Epoch 6/25] [Batch 569/995] [D loss: 0.233939, acc:  66%] [G loss: 4.446751, adv: 0.382640, recon: 0.152985, id: 0.310416] time: 4:37:02.370503
# Inside 2nd for loop
# [Epoch 6/25] [Batch 570/995] [D loss: 0.233231, acc:  62%] [G loss: 3.196157, adv: 0.375184, recon: 0.097711, id: 0.324147] time: 4:37:04.997745
# Inside 2nd for loop
# [Epoch 6/25] [Batch 571/995] [D loss: 0.227624, acc:  68%] [G loss: 2.335284, adv: 0.463711, recon: 0.056579, id: 0.105402] time: 4:37:07.634159
# Inside 2nd for loop
# [Epoch 6/25] [Batch 572/995] [D loss: 0.168396, acc:  76%] [G loss: 3.323127, adv: 0.475076, recon: 0.095070, id: 0.153108] time: 4:37:10.194926
# Inside 2nd for loop
# [Epoch 6/25] [Batch 573/995] [D loss: 0.229710, acc:  64%] [G loss: 2.819839, adv: 0.422994, recon: 0.082083, id: 0.241714] time: 4:37:12.693259
# Inside 2nd for loop
# [Epoch 6/25] [Batch 574/995] [D loss: 0.212286, acc:  58%] [G loss: 3.950328, adv: 0.442566, recon: 0.119011, id: 0.228781] time: 4:37:15.212149
# Inside 2nd for loop
# [Epoch 6/25] [Batch 575/995] [D loss: 0.191363, acc:  76%] [G loss: 3.232649, adv: 0.545270, recon: 0.084511, id: 0.302519] time: 4:37:17.716367
# Inside 2nd for loop
# [Epoch 6/25] [Batch 576/995] [D loss: 0.359928, acc:  54%] [G loss: 3.534271, adv: 0.399811, recon: 0.113147, id: 0.306122] time: 4:37:20.226613
# Inside 2nd for loop
# [Epoch 6/25] [Batch 577/995] [D loss: 0.244904, acc:  55%] [G loss: 3.968761, adv: 0.371573, recon: 0.130325, id: 0.350540] time: 4:37:22.747407
# Inside 2nd for loop
# [Epoch 6/25] [Batch 578/995] [D loss: 0.126905, acc:  82%] [G loss: 3.993238, adv: 0.567495, recon: 0.116842, id: 0.309835] time: 4:37:25.281061
# Inside 2nd for loop
# [Epoch 6/25] [Batch 579/995] [D loss: 0.311626, acc:  46%] [G loss: 5.327507, adv: 0.360404, recon: 0.195600, id: 0.537914] time: 4:37:27.739249
# Inside 2nd for loop
# [Epoch 6/25] [Batch 580/995] [D loss: 0.170711, acc:  76%] [G loss: 3.553027, adv: 0.601901, recon: 0.091467, id: 0.316557] time: 4:37:30.270312
# Inside 2nd for loop
# [Epoch 6/25] [Batch 581/995] [D loss: 0.219838, acc:  59%] [G loss: 2.784144, adv: 0.506105, recon: 0.071902, id: 0.206775] time: 4:37:32.902469
# Inside 2nd for loop
# [Epoch 6/25] [Batch 582/995] [D loss: 0.298945, acc:  30%] [G loss: 3.610253, adv: 0.342584, recon: 0.116302, id: 0.401238] time: 4:37:35.542824
# Inside 2nd for loop
# [Epoch 6/25] [Batch 583/995] [D loss: 0.455020, acc:  19%] [G loss: 3.357610, adv: 0.319072, recon: 0.110879, id: 0.256428] time: 4:37:38.172223
# Inside 2nd for loop
# [Epoch 6/25] [Batch 584/995] [D loss: 0.137795, acc:  85%] [G loss: 3.404635, adv: 0.587105, recon: 0.084989, id: 0.388621] time: 4:37:40.814785
# Inside 2nd for loop
# [Epoch 6/25] [Batch 585/995] [D loss: 0.307614, acc:  46%] [G loss: 3.383383, adv: 0.414366, recon: 0.103463, id: 0.281231] time: 4:37:43.417844
# Inside 2nd for loop
# [Epoch 6/25] [Batch 586/995] [D loss: 0.243591, acc:  67%] [G loss: 3.830575, adv: 0.476554, recon: 0.116795, id: 0.269301] time: 4:37:45.964157
# Inside 2nd for loop
# [Epoch 6/25] [Batch 587/995] [D loss: 0.244845, acc:  50%] [G loss: 3.550261, adv: 0.358230, recon: 0.121540, id: 0.125250] time: 4:37:48.526236
# Inside 2nd for loop
# [Epoch 6/25] [Batch 588/995] [D loss: 0.144654, acc:  87%] [G loss: 3.126114, adv: 0.519142, recon: 0.087644, id: 0.150814] time: 4:37:51.085947
# Inside 2nd for loop
# [Epoch 6/25] [Batch 589/995] [D loss: 0.211069, acc:  60%] [G loss: 3.822274, adv: 0.494043, recon: 0.109810, id: 0.363341] time: 4:37:53.683211
# Inside 2nd for loop
# [Epoch 6/25] [Batch 590/995] [D loss: 0.273416, acc:  43%] [G loss: 3.203040, adv: 0.379870, recon: 0.098433, id: 0.110910] time: 4:37:56.315494
# Inside 2nd for loop
# [Epoch 6/25] [Batch 591/995] [D loss: 0.182294, acc:  79%] [G loss: 3.934278, adv: 0.466960, recon: 0.123551, id: 0.294196] time: 4:37:58.932149
# Inside 2nd for loop
# [Epoch 6/25] [Batch 592/995] [D loss: 0.210995, acc:  67%] [G loss: 3.598772, adv: 0.463378, recon: 0.108818, id: 0.204866] time: 4:38:01.580678
# Inside 2nd for loop
# [Epoch 6/25] [Batch 593/995] [D loss: 0.091966, acc:  96%] [G loss: 4.717313, adv: 0.573362, recon: 0.140488, id: 0.451673] time: 4:38:04.206003
# Inside 2nd for loop
# [Epoch 6/25] [Batch 594/995] [D loss: 0.135545, acc:  89%] [G loss: 3.723984, adv: 0.515211, recon: 0.102475, id: 0.270803] time: 4:38:06.828486
# Inside 2nd for loop
# [Epoch 6/25] [Batch 595/995] [D loss: 0.216265, acc:  60%] [G loss: 3.332581, adv: 0.457825, recon: 0.087625, id: 0.277500] time: 4:38:09.399442
# Inside 2nd for loop
# [Epoch 6/25] [Batch 596/995] [D loss: 0.141151, acc:  82%] [G loss: 3.788736, adv: 0.707704, recon: 0.088214, id: 0.295523] time: 4:38:11.869368
# Inside 2nd for loop
# [Epoch 6/25] [Batch 597/995] [D loss: 0.095852, acc:  98%] [G loss: 3.374485, adv: 0.583538, recon: 0.091622, id: 0.116182] time: 4:38:14.343838
# Inside 2nd for loop
# [Epoch 6/25] [Batch 598/995] [D loss: 0.229885, acc:  55%] [G loss: 3.934868, adv: 0.503386, recon: 0.115192, id: 0.202528] time: 4:38:16.841280
# Inside 2nd for loop
# [Epoch 6/25] [Batch 599/995] [D loss: 0.150127, acc:  82%] [G loss: 3.357523, adv: 0.493008, recon: 0.099668, id: 0.155975] time: 4:38:19.298992
# Inside 2nd for loop
# [Epoch 6/25] [Batch 600/995] [D loss: 0.561359, acc:  49%] [G loss: 3.440492, adv: 0.344156, recon: 0.114459, id: 0.269378] time: 4:38:21.759942
# Inside 2nd for loop
# [Epoch 6/25] [Batch 601/995] [D loss: 0.222570, acc:  60%] [G loss: 3.490604, adv: 0.599803, recon: 0.086200, id: 0.390208] time: 4:38:25.762676
# Inside 2nd for loop
# [Epoch 6/25] [Batch 602/995] [D loss: 0.282987, acc:  52%] [G loss: 4.063454, adv: 0.452272, recon: 0.121308, id: 0.412450] time: 4:38:28.312744
# Inside 2nd for loop
# [Epoch 6/25] [Batch 603/995] [D loss: 0.338578, acc:  39%] [G loss: 3.286432, adv: 0.411056, recon: 0.100826, id: 0.249352] time: 4:38:30.928260
# Inside 2nd for loop
# [Epoch 6/25] [Batch 604/995] [D loss: 0.231860, acc:  58%] [G loss: 2.434718, adv: 0.426432, recon: 0.063940, id: 0.208133] time: 4:38:33.539487
# Inside 2nd for loop
# [Epoch 6/25] [Batch 605/995] [D loss: 0.171186, acc:  72%] [G loss: 3.285306, adv: 0.483814, recon: 0.091635, id: 0.149050] time: 4:38:36.224507
# Inside 2nd for loop
# [Epoch 6/25] [Batch 606/995] [D loss: 0.297886, acc:  57%] [G loss: 2.732909, adv: 0.397428, recon: 0.070549, id: 0.102718] time: 4:38:38.865529
# Inside 2nd for loop
# [Epoch 6/25] [Batch 607/995] [D loss: 0.145217, acc:  86%] [G loss: 3.528205, adv: 0.593898, recon: 0.091571, id: 0.177315] time: 4:38:41.508846
# Inside 2nd for loop
# [Epoch 6/25] [Batch 608/995] [D loss: 0.114898, acc:  96%] [G loss: 3.134621, adv: 0.515412, recon: 0.078057, id: 0.199046] time: 4:38:44.153532
# Inside 2nd for loop
# [Epoch 6/25] [Batch 609/995] [D loss: 0.361816, acc:  33%] [G loss: 3.329068, adv: 0.342396, recon: 0.104764, id: 0.294450] time: 4:38:46.773243
# Inside 2nd for loop
# [Epoch 6/25] [Batch 610/995] [D loss: 0.213119, acc:  69%] [G loss: 2.984193, adv: 0.407251, recon: 0.088480, id: 0.202959] time: 4:38:49.387914
# Inside 2nd for loop
# [Epoch 6/25] [Batch 611/995] [D loss: 0.293054, acc:  35%] [G loss: 3.128538, adv: 0.281347, recon: 0.098692, id: 0.304994] time: 4:38:52.028443
# Inside 2nd for loop
# [Epoch 6/25] [Batch 612/995] [D loss: 0.325509, acc:  33%] [G loss: 3.398824, adv: 0.373146, recon: 0.098140, id: 0.383905] time: 4:38:54.667972
# Inside 2nd for loop
# [Epoch 6/25] [Batch 613/995] [D loss: 0.219829, acc:  71%] [G loss: 3.475155, adv: 0.448317, recon: 0.106344, id: 0.276978] time: 4:38:57.331991
# Inside 2nd for loop
# [Epoch 6/25] [Batch 614/995] [D loss: 0.159357, acc:  90%] [G loss: 3.660182, adv: 0.429580, recon: 0.115981, id: 0.258118] time: 4:38:59.962901
# Inside 2nd for loop
# [Epoch 6/25] [Batch 615/995] [D loss: 0.169933, acc:  73%] [G loss: 3.779587, adv: 0.539773, recon: 0.111797, id: 0.266420] time: 4:39:02.606169
# Inside 2nd for loop
# [Epoch 6/25] [Batch 616/995] [D loss: 0.463452, acc:  46%] [G loss: 4.542066, adv: 0.450923, recon: 0.133455, id: 0.462654] time: 4:39:05.209609
# Inside 2nd for loop
